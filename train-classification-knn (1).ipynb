# %% [markdown]
# <img src="http://vision.skills.network/logo-light.png" width="400" alt="CV Studio logo"  />

# %% [markdown]
# <h2>KNN Image Classification with OpenCV and <a href="https://vision.skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-cvstudio-2021-01-01"> Computer Vision Learning Studio (CV Studio) </a></h2>
# <h3>Project: Training_an_image_classifier_with_KNN</h3>
# <h3>Training Run: Train - KNN image classifier</h3>

# %% [markdown]
# Estimated time needed: **60** minutes

# %% [markdown]
# You will learn how to train a K-Nearest Neighbours (k-NN), a supervised Machine Learning algorithm to classify your images. KNN learns from a labeled training set by taking in the training data along with its labels and learns to map the input to its desired output.

# %% [markdown]
# ## Objectives

# %% [markdown]
# We will be classifying cat and dog images using <code>OpenCV</code> and <a href="https://vision.skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-cvstudio-2021-01-01"> Computer Vision Learning Studio (CV Studio)</a>. CV Studio is a fast, easy and collaborative open-source Computer Vision tool for teams and individuals. You can upload your datasets and label them yourself. If you created a separate folder for each image class, the tool will do the labeling for you.

# %% [markdown]
# <ul>
#     <li>This tool contains the following sections:
#         <ul>
#             <li>Import Libraries</li>
#             <li>Load Images in Python</li>
#             <li>Plotting an Image </li>
#             <li>Gray Scale Images </li>
#             <li>k-NN for Image classification </li>
#             <li>Save your model to CVStudio</li>
#         </ul>
#     </li>
#
# </ul>

# %% [markdown]
# ***

# %% [markdown]
# ## Load Important Libraries

# %% [markdown]
# Libraries for data processing and visualization:

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from imutils import paths
import seaborn as sns
import random
import time
from datetime import datetime

# %% [markdown]
# Libraries for image pre-processing and classification:

# %%
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/utils/validation.py:37: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LARGE_SPARSE_SUPPORTED = LooseVersion(scipy_version) >= '0.14.0'

# %% [markdown]
# Libraries for OS and Cloud:

# %%
import os
from skillsnetwork import cvstudio

# %% [markdown]
# ## Download Your Images and Annotations

# %% [markdown]
# Now, let's initialize and download the images from the project you just created in CV Studio.

# %%
# Initialize the CV Studio Client
cvstudioClient = cvstudio.CVStudio()

# Download All Images
cvstudioClient.downloadAll()
# Out:
#   7%|▋         | 292/4200 [00:35<06:45,  9.63it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#   7%|▋         | 294/4200 [00:35<07:09,  9.10it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#   9%|▉         | 390/4200 [00:44<06:08, 10.33it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#   9%|▉         | 392/4200 [00:44<06:34,  9.65it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  12%|█▏        | 483/4200 [00:52<06:07, 10.12it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  12%|█▏        | 509/4200 [00:54<05:11, 11.86it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  16%|█▌        | 653/4200 [01:08<05:45, 10.26it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  26%|██▌       | 1102/4200 [01:59<05:02, 10.23it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  30%|███       | 1279/4200 [02:17<04:58,  9.80it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  31%|███       | 1285/4200 [02:18<05:04,  9.57it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  31%|███       | 1289/4200 [02:18<05:05,  9.54it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  31%|███       | 1291/4200 [02:19<06:45,  7.17it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  43%|████▎     | 1819/4200 [03:18<04:00,  9.90it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  44%|████▍     | 1861/4200 [03:22<03:25, 11.36it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  44%|████▍     | 1865/4200 [03:22<04:05,  9.50it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  51%|█████▏    | 2154/4200 [03:50<03:13, 10.60it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  52%|█████▏    | 2172/4200 [03:52<03:32,  9.54it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  53%|█████▎    | 2240/4200 [03:58<03:24,  9.57it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  54%|█████▎    | 2256/4200 [03:59<03:04, 10.54it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  54%|█████▍    | 2259/4200 [04:00<04:13,  7.66it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  55%|█████▌    | 2328/4200 [04:07<03:02, 10.26it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  56%|█████▌    | 2336/4200 [04:08<03:07,  9.96it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  56%|█████▌    | 2339/4200 [04:08<03:39,  8.47it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  56%|█████▌    | 2356/4200 [04:10<02:53, 10.63it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  56%|█████▌    | 2358/4200 [04:10<03:44,  8.22it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  57%|█████▋    | 2388/4200 [04:13<03:12,  9.44it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  57%|█████▋    | 2397/4200 [04:14<03:05,  9.72it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  57%|█████▋    | 2411/4200 [04:15<03:01,  9.84it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  59%|█████▉    | 2479/4200 [04:22<02:59,  9.60it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  59%|█████▉    | 2483/4200 [04:22<03:08,  9.12it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  59%|█████▉    | 2487/4200 [04:23<03:29,  8.16it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  61%|██████    | 2548/4200 [04:29<03:17,  8.36it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  61%|██████    | 2549/4200 [04:29<03:29,  7.90it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  61%|██████    | 2555/4200 [04:30<03:00,  9.09it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  61%|██████    | 2565/4200 [04:31<02:38, 10.34it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  61%|██████    | 2567/4200 [04:31<03:02,  8.92it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  61%|██████    | 2568/4200 [04:31<03:14,  8.38it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  61%|██████    | 2570/4200 [04:31<03:15,  8.33it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  61%|██████    | 2572/4200 [04:32<03:32,  7.67it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  61%|██████▏   | 2573/4200 [04:32<03:40,  7.39it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  61%|██████▏   | 2575/4200 [04:32<03:51,  7.02it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  61%|██████▏   | 2576/4200 [04:32<03:56,  6.87it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  62%|██████▏   | 2590/4200 [04:34<02:58,  9.02it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  62%|██████▏   | 2591/4200 [04:34<03:09,  8.47it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  62%|██████▏   | 2593/4200 [04:34<03:12,  8.35it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  62%|██████▏   | 2595/4200 [04:34<03:11,  8.37it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  62%|██████▏   | 2597/4200 [04:35<03:16,  8.15it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  62%|██████▏   | 2600/4200 [04:35<03:26,  7.73it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  62%|██████▏   | 2602/4200 [04:35<03:31,  7.55it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  62%|██████▏   | 2603/4200 [04:35<03:38,  7.30it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  62%|██████▏   | 2605/4200 [04:36<03:23,  7.84it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  62%|██████▏   | 2608/4200 [04:36<03:26,  7.72it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  62%|██████▏   | 2612/4200 [04:37<03:23,  7.82it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  62%|██████▏   | 2615/4200 [04:37<03:16,  8.06it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  62%|██████▏   | 2617/4200 [04:37<03:16,  8.04it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  62%|██████▏   | 2620/4200 [04:37<03:10,  8.30it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  62%|██████▏   | 2621/4200 [04:38<04:09,  6.34it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  62%|██████▏   | 2623/4200 [04:38<03:43,  7.05it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  63%|██████▎   | 2637/4200 [04:39<02:38,  9.85it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  63%|██████▎   | 2641/4200 [04:40<02:32, 10.24it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  63%|██████▎   | 2645/4200 [04:40<02:41,  9.65it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  63%|██████▎   | 2647/4200 [04:40<02:47,  9.29it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  63%|██████▎   | 2650/4200 [04:41<03:20,  7.73it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  63%|██████▎   | 2652/4200 [04:41<03:56,  6.55it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  63%|██████▎   | 2653/4200 [04:41<04:39,  5.53it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  63%|██████▎   | 2655/4200 [04:42<04:04,  6.32it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  63%|██████▎   | 2657/4200 [04:42<04:01,  6.39it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  63%|██████▎   | 2659/4200 [04:42<03:56,  6.51it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  63%|██████▎   | 2664/4200 [04:43<02:57,  8.63it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  63%|██████▎   | 2666/4200 [04:43<03:02,  8.42it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  64%|██████▎   | 2668/4200 [04:43<03:20,  7.65it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  64%|██████▎   | 2669/4200 [04:43<03:26,  7.40it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  64%|██████▎   | 2670/4200 [04:44<03:33,  7.16it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  64%|██████▎   | 2674/4200 [04:44<02:58,  8.54it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  64%|██████▍   | 2678/4200 [04:44<02:25, 10.47it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  64%|██████▍   | 2681/4200 [04:45<03:02,  8.34it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  64%|██████▍   | 2682/4200 [04:45<03:10,  7.96it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  64%|██████▍   | 2694/4200 [04:46<03:05,  8.13it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  64%|██████▍   | 2696/4200 [04:47<03:37,  6.91it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  64%|██████▍   | 2697/4200 [04:47<03:39,  6.86it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  64%|██████▍   | 2699/4200 [04:47<03:43,  6.71it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  64%|██████▍   | 2707/4200 [04:48<02:47,  8.93it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  64%|██████▍   | 2708/4200 [04:48<02:59,  8.30it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  64%|██████▍   | 2709/4200 [04:48<04:04,  6.10it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  65%|██████▍   | 2711/4200 [04:49<03:57,  6.26it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  65%|██████▍   | 2723/4200 [04:50<02:32,  9.70it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  65%|██████▍   | 2725/4200 [04:50<02:36,  9.42it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  65%|██████▍   | 2727/4200 [04:50<02:59,  8.23it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  65%|██████▍   | 2729/4200 [04:51<02:56,  8.35it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  65%|██████▌   | 2731/4200 [04:51<03:11,  7.68it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  65%|██████▌   | 2734/4200 [04:51<02:59,  8.15it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  65%|██████▌   | 2737/4200 [04:52<03:00,  8.10it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  65%|██████▌   | 2739/4200 [04:52<02:56,  8.29it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  65%|██████▌   | 2743/4200 [04:52<02:42,  8.97it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  66%|██████▌   | 2763/4200 [04:54<02:03, 11.61it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  66%|██████▌   | 2771/4200 [04:55<02:53,  8.25it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  67%|██████▋   | 2796/4200 [04:57<02:08, 10.95it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  67%|██████▋   | 2799/4200 [04:58<02:45,  8.46it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  67%|██████▋   | 2828/4200 [05:01<02:24,  9.51it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  68%|██████▊   | 2844/4200 [05:02<02:14, 10.09it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  68%|██████▊   | 2850/4200 [05:03<02:16,  9.88it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  68%|██████▊   | 2852/4200 [05:03<02:24,  9.33it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  68%|██████▊   | 2853/4200 [05:03<03:07,  7.17it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  68%|██████▊   | 2855/4200 [05:04<03:18,  6.77it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  68%|██████▊   | 2858/4200 [05:04<03:04,  7.28it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  68%|██████▊   | 2859/4200 [05:04<02:56,  7.61it/s]
# ...
# Retrying download
#  97%|█████████▋| 4094/4200 [08:00<00:16,  6.51it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4095/4200 [08:00<00:16,  6.52it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4097/4200 [08:01<00:13,  7.44it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4099/4200 [08:01<00:14,  7.12it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4100/4200 [08:01<00:14,  6.98it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4102/4200 [08:01<00:14,  6.80it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4103/4200 [08:01<00:14,  6.80it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4105/4200 [08:02<00:13,  6.80it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4106/4200 [08:02<00:13,  6.72it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4108/4200 [08:02<00:15,  6.07it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  98%|█████████▊| 4109/4200 [08:02<00:14,  6.20it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4111/4200 [08:03<00:13,  6.40it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  98%|█████████▊| 4112/4200 [08:03<00:13,  6.52it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4114/4200 [08:03<00:13,  6.58it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  98%|█████████▊| 4115/4200 [08:03<00:13,  6.47it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  98%|█████████▊| 4117/4200 [08:04<00:11,  7.29it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4118/4200 [08:04<00:11,  7.13it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4120/4200 [08:04<00:11,  7.10it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4122/4200 [08:04<00:11,  6.83it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  98%|█████████▊| 4123/4200 [08:04<00:11,  6.79it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  98%|█████████▊| 4127/4200 [08:05<00:08,  8.38it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4128/4200 [08:05<00:10,  7.14it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4129/4200 [08:05<00:10,  6.58it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4131/4200 [08:06<00:11,  6.24it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  98%|█████████▊| 4132/4200 [08:06<00:12,  5.64it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4133/4200 [08:06<00:11,  5.89it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
#  98%|█████████▊| 4134/4200 [08:06<00:10,  6.10it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  99%|█████████▉| 4148/4200 [08:08<00:05,  8.79it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
#  99%|█████████▉| 4163/4200 [08:09<00:03,  9.63it/s]
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# Retrying download
# Exception An error occurred (404) when calling the HeadObject operation: Not Found
# 100%|██████████| 4200/4200 [08:12<00:00,  8.52it/s]

# %% [markdown]
# 👈🏾 You can check the side panel to see if your images downloaded.

# %% [markdown]
# Get the annotations from the project you downloaded from CV Studio:

# %%
annotations = cvstudioClient.get_annotations()

# %% [markdown]
# Let's view the format of the annotations we've just downloaded. The following code will display only the first 5 annotations. The annotations will come in a JSON file. What you can see is the image name as the key and `dog` as label object.

# %%
first_five = {k: annotations["annotations"][k] for k in list(annotations["annotations"])[:5]}
first_five
# Out:
# {'37e1580b-33bd-4997-b632-0516b99881f0.jpg': [{'label': 'cat'}],
#  '07944ff7-562a-4d3d-aa5f-2733a7edac27.jpg': [{'label': 'dog'}],
#  'b51910dc-2c88-4472-8aa4-1cc788520ed4.jpg': [{'label': 'dog'}],
#  '1e2f77e9-3745-417e-80f1-f065957f4482.jpg': [{'label': 'dog'}],
#  'ce2f0b14-2dc0-4f68-a4e1-f73d406d4bc2.jpg': [{'label': 'cat'}]}

# %% [markdown]
# # Load and Plot and Image
#
# We will train and classify your images using the k-NN classifier using the <code>OpenCV</code> library. Before we start, let's get the images and take a look at some of them.

# %% [markdown]
# We will pick random images and take a look:

# %%
random_filename = 'images/' + random.choice(list(annotations["annotations"].keys()))

# %% [markdown]
# Plot, read and show a random image using the `cv2.imread` and the `matplotlib` library.
#
# We will also change the color space to `RGB` so we can plot it since `OpenCV` reads images as `BGR`. Early developers at `OpenCV` chose `BGR` color format because it was the format that was popular among camera manufacturers and software providers.

# %%
sample_image = cv2.imread(random_filename)
## Convert to RGB
image = cv2.cvtColor(sample_image, cv2.COLOR_BGR2RGB)
## Now plot the image
plt.figure(figsize=(10,10))
plt.imshow(image, cmap = "gray")
plt.show()

# %%
## if you plot with sample_image, you will observe a difference in the color space
## uncomment to try it out
# plt.imshow(sample_image)
# plt.show()

# %% [markdown]
# To perform KNN on the dataset, we will need to process the data. I will use the sample image to explain each line of code.

# %% [markdown]
# Convert image to grayscale - grayscale simplifies the algorithm and reduces computational requirements.

# %%
sample_image = cv2.cvtColor(sample_image,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10,10))
plt.imshow(sample_image, cmap = "gray")
plt.show()

# %% [markdown]
# Resize image - resizing image helps the algorithm train faster.

# %%
sample_image = cv2.resize(sample_image, (32, 32))
plt.imshow(sample_image, cmap = "gray")
plt.show()

# %% [markdown]
# Flatten image - makes the image a numpy array for the algorithm to handle and recognize.

# %%
pixels = sample_image.flatten()
pixels
# Out:
# array([110, 115, 160, ..., 117, 141, 100], dtype=uint8)

# %% [markdown]
# ## Repeat the Process Above for All Images

# %% [markdown]
# We will now repeat the same process above to load and process all the images you’ve annotated and label each picture. KNN is supervised machine learning algorithm, therefore we have to explicitly create labels for the machine.
#
# Depending on how much data you have, this will take a while to run...

# %%
image_paths = list(paths.list_images('images'))
train_images = []
train_labels = []
class_object = annotations['labels']

# loop over the input images
for (i, image_path) in enumerate(image_paths):
    #read image
    image = cv2.imread(image_path)
    #make images gray
    image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    #label image using the annotations
    label = class_object.index(annotations["annotations"][image_path[7:]][0]['label'])
    tmp_label = annotations["annotations"][image_path[7:]][0]['label']
    # resize image
    image = cv2.resize(image, (32, 32))
    # flatten the image
    pixels = image.flatten()
    #Append flattened image to
    train_images.append(pixels)
    train_labels.append(label)
    print('Loaded...', '\U0001F483', 'Image', str(i+1), 'is a', tmp_label)
# Out:
# Loaded... 💃 Image 1 is a dog
# Loaded... 💃 Image 2 is a cat
# Loaded... 💃 Image 3 is a dog
# Loaded... 💃 Image 4 is a dog
# Loaded... 💃 Image 5 is a cat
# Loaded... 💃 Image 6 is a cat
# Loaded... 💃 Image 7 is a cat
# Loaded... 💃 Image 8 is a cat
# Loaded... 💃 Image 9 is a dog
# Loaded... 💃 Image 10 is a cat
# Loaded... 💃 Image 11 is a cat
# Loaded... 💃 Image 12 is a dog
# Loaded... 💃 Image 13 is a cat
# Loaded... 💃 Image 14 is a dog
# Loaded... 💃 Image 15 is a dog
# Loaded... 💃 Image 16 is a dog
# Loaded... 💃 Image 17 is a cat
# Loaded... 💃 Image 18 is a dog
# Loaded... 💃 Image 19 is a dog
# Loaded... 💃 Image 20 is a cat
# Loaded... 💃 Image 21 is a dog
# Loaded... 💃 Image 22 is a dog
# Loaded... 💃 Image 23 is a dog
# Loaded... 💃 Image 24 is a cat
# Loaded... 💃 Image 25 is a dog
# Loaded... 💃 Image 26 is a cat
# Loaded... 💃 Image 27 is a dog
# Loaded... 💃 Image 28 is a cat
# Loaded... 💃 Image 29 is a dog
# Loaded... 💃 Image 30 is a cat
# Loaded... 💃 Image 31 is a cat
# Loaded... 💃 Image 32 is a cat
# Loaded... 💃 Image 33 is a dog
# Loaded... 💃 Image 34 is a cat
# Loaded... 💃 Image 35 is a cat
# Loaded... 💃 Image 36 is a cat
# Loaded... 💃 Image 37 is a cat
# Loaded... 💃 Image 38 is a cat
# Loaded... 💃 Image 39 is a cat
# Loaded... 💃 Image 40 is a dog
# Loaded... 💃 Image 41 is a cat
# Loaded... 💃 Image 42 is a cat
# Loaded... 💃 Image 43 is a cat
# Loaded... 💃 Image 44 is a dog
# Loaded... 💃 Image 45 is a cat
# Loaded... 💃 Image 46 is a dog
# Loaded... 💃 Image 47 is a dog
# Loaded... 💃 Image 48 is a cat
# Loaded... 💃 Image 49 is a cat
# Loaded... 💃 Image 50 is a dog
# Loaded... 💃 Image 51 is a cat
# Loaded... 💃 Image 52 is a cat
# Loaded... 💃 Image 53 is a cat
# Loaded... 💃 Image 54 is a cat
# Loaded... 💃 Image 55 is a dog
# Loaded... 💃 Image 56 is a dog
# Loaded... 💃 Image 57 is a dog
# Loaded... 💃 Image 58 is a cat
# Loaded... 💃 Image 59 is a dog
# Loaded... 💃 Image 60 is a dog
# Loaded... 💃 Image 61 is a cat
# Loaded... 💃 Image 62 is a cat
# Loaded... 💃 Image 63 is a dog
# Loaded... 💃 Image 64 is a cat
# Loaded... 💃 Image 65 is a cat
# Loaded... 💃 Image 66 is a dog
# Loaded... 💃 Image 67 is a dog
# Loaded... 💃 Image 68 is a cat
# Loaded... 💃 Image 69 is a cat
# Loaded... 💃 Image 70 is a cat
# Loaded... 💃 Image 71 is a cat
# Loaded... 💃 Image 72 is a dog
# Loaded... 💃 Image 73 is a dog
# Loaded... 💃 Image 74 is a dog
# Loaded... 💃 Image 75 is a cat
# Loaded... 💃 Image 76 is a cat
# Loaded... 💃 Image 77 is a dog
# Loaded... 💃 Image 78 is a cat
# Loaded... 💃 Image 79 is a dog
# Loaded... 💃 Image 80 is a dog
# Loaded... 💃 Image 81 is a dog
# Loaded... 💃 Image 82 is a cat
# Loaded... 💃 Image 83 is a cat
# Loaded... 💃 Image 84 is a dog
# Loaded... 💃 Image 85 is a cat
# Loaded... 💃 Image 86 is a cat
# Loaded... 💃 Image 87 is a dog
# Loaded... 💃 Image 88 is a cat
# Loaded... 💃 Image 89 is a cat
# Loaded... 💃 Image 90 is a dog
# Loaded... 💃 Image 91 is a cat
# Loaded... 💃 Image 92 is a cat
# Loaded... 💃 Image 93 is a cat
# Loaded... 💃 Image 94 is a cat
# Loaded... 💃 Image 95 is a dog
# Loaded... 💃 Image 96 is a cat
# Loaded... 💃 Image 97 is a cat
# Loaded... 💃 Image 98 is a dog
# Loaded... 💃 Image 99 is a dog
# Loaded... 💃 Image 100 is a cat
# Loaded... 💃 Image 101 is a cat
# Loaded... 💃 Image 102 is a cat
# Loaded... 💃 Image 103 is a dog
# Loaded... 💃 Image 104 is a cat
# Loaded... 💃 Image 105 is a cat
# Loaded... 💃 Image 106 is a cat
# Loaded... 💃 Image 107 is a dog
# Loaded... 💃 Image 108 is a cat
# Loaded... 💃 Image 109 is a cat
# Loaded... 💃 Image 110 is a dog
# Loaded... 💃 Image 111 is a cat
# Loaded... 💃 Image 112 is a dog
# Loaded... 💃 Image 113 is a cat
# Loaded... 💃 Image 114 is a cat
# Loaded... 💃 Image 115 is a cat
# Loaded... 💃 Image 116 is a dog
# Loaded... 💃 Image 117 is a cat
# Loaded... 💃 Image 118 is a cat
# Loaded... 💃 Image 119 is a dog
# Loaded... 💃 Image 120 is a dog
# Loaded... 💃 Image 121 is a cat
# Loaded... 💃 Image 122 is a dog
# Loaded... 💃 Image 123 is a dog
# Loaded... 💃 Image 124 is a cat
# Loaded... 💃 Image 125 is a cat
# Loaded... 💃 Image 126 is a dog
# Loaded... 💃 Image 127 is a cat
# Loaded... 💃 Image 128 is a cat
# Loaded... 💃 Image 129 is a cat
# Loaded... 💃 Image 130 is a cat
# Loaded... 💃 Image 131 is a dog
# Loaded... 💃 Image 132 is a dog
# Loaded... 💃 Image 133 is a cat
# Loaded... 💃 Image 134 is a cat
# Loaded... 💃 Image 135 is a cat
# Loaded... 💃 Image 136 is a cat
# Loaded... 💃 Image 137 is a cat
# Loaded... 💃 Image 138 is a dog
# Loaded... 💃 Image 139 is a dog
# Loaded... 💃 Image 140 is a cat
# Loaded... 💃 Image 141 is a dog
# Loaded... 💃 Image 142 is a cat
# Loaded... 💃 Image 143 is a cat
# Loaded... 💃 Image 144 is a cat
# Loaded... 💃 Image 145 is a cat
# Loaded... 💃 Image 146 is a cat
# Loaded... 💃 Image 147 is a cat
# Loaded... 💃 Image 148 is a dog
# Loaded... 💃 Image 149 is a cat
# Loaded... 💃 Image 150 is a cat
# Loaded... 💃 Image 151 is a cat
# Loaded... 💃 Image 152 is a cat
# Loaded... 💃 Image 153 is a dog
# Loaded... 💃 Image 154 is a cat
# Loaded... 💃 Image 155 is a dog
# Loaded... 💃 Image 156 is a dog
# Loaded... 💃 Image 157 is a cat
# Loaded... 💃 Image 158 is a cat
# Loaded... 💃 Image 159 is a cat
# Loaded... 💃 Image 160 is a cat
# Loaded... 💃 Image 161 is a cat
# Loaded... 💃 Image 162 is a cat
# Loaded... 💃 Image 163 is a cat
# Loaded... 💃 Image 164 is a dog
# Loaded... 💃 Image 165 is a cat
# Loaded... 💃 Image 166 is a cat
# Loaded... 💃 Image 167 is a cat
# Loaded... 💃 Image 168 is a dog
# Loaded... 💃 Image 169 is a cat
# Loaded... 💃 Image 170 is a dog
# Loaded... 💃 Image 171 is a cat
# Loaded... 💃 Image 172 is a dog
# Loaded... 💃 Image 173 is a dog
# Loaded... 💃 Image 174 is a dog
# Loaded... 💃 Image 175 is a dog
# Loaded... 💃 Image 176 is a dog
# Loaded... 💃 Image 177 is a cat
# Loaded... 💃 Image 178 is a dog
# Loaded... 💃 Image 179 is a cat
# Loaded... 💃 Image 180 is a cat
# Loaded... 💃 Image 181 is a cat
# Loaded... 💃 Image 182 is a dog
# Loaded... 💃 Image 183 is a dog
# Loaded... 💃 Image 184 is a cat
# Loaded... 💃 Image 185 is a cat
# Loaded... 💃 Image 186 is a dog
# Loaded... 💃 Image 187 is a dog
# Loaded... 💃 Image 188 is a cat
# Loaded... 💃 Image 189 is a dog
# Loaded... 💃 Image 190 is a cat
# Loaded... 💃 Image 191 is a cat
# Loaded... 💃 Image 192 is a dog
# Loaded... 💃 Image 193 is a cat
# Loaded... 💃 Image 194 is a cat
# Loaded... 💃 Image 195 is a dog
# Loaded... 💃 Image 196 is a dog
# Loaded... 💃 Image 197 is a dog
# Loaded... 💃 Image 198 is a cat
# Loaded... 💃 Image 199 is a cat
# Loaded... 💃 Image 200 is a cat
# Loaded... 💃 Image 201 is a cat
# Loaded... 💃 Image 202 is a cat
# Loaded... 💃 Image 203 is a cat
# Loaded... 💃 Image 204 is a dog
# Loaded... 💃 Image 205 is a dog
# Loaded... 💃 Image 206 is a dog
# Loaded... 💃 Image 207 is a cat
# Loaded... 💃 Image 208 is a cat
# Loaded... 💃 Image 209 is a dog
# Loaded... 💃 Image 210 is a cat
# Loaded... 💃 Image 211 is a dog
# Loaded... 💃 Image 212 is a cat
# Loaded... 💃 Image 213 is a cat
# Loaded... 💃 Image 214 is a cat
# Loaded... 💃 Image 215 is a dog
# Loaded... 💃 Image 216 is a dog
# Loaded... 💃 Image 217 is a cat
# Loaded... 💃 Image 218 is a dog
# Loaded... 💃 Image 219 is a dog
# Loaded... 💃 Image 220 is a cat
# Loaded... 💃 Image 221 is a cat
# Loaded... 💃 Image 222 is a dog
# Loaded... 💃 Image 223 is a cat
# Loaded... 💃 Image 224 is a cat
# Loaded... 💃 Image 225 is a cat
# Loaded... 💃 Image 226 is a cat
# Loaded... 💃 Image 227 is a dog
# Loaded... 💃 Image 228 is a dog
# Loaded... 💃 Image 229 is a dog
# Loaded... 💃 Image 230 is a dog
# Loaded... 💃 Image 231 is a cat
# Loaded... 💃 Image 232 is a cat
# Loaded... 💃 Image 233 is a dog
# Loaded... 💃 Image 234 is a dog
# Loaded... 💃 Image 235 is a cat
# Loaded... 💃 Image 236 is a dog
# Loaded... 💃 Image 237 is a cat
# Loaded... 💃 Image 238 is a dog
# Loaded... 💃 Image 239 is a dog
# Loaded... 💃 Image 240 is a cat
# Loaded... 💃 Image 241 is a dog
# Loaded... 💃 Image 242 is a cat
# Loaded... 💃 Image 243 is a cat
# Loaded... 💃 Image 244 is a cat
# Loaded... 💃 Image 245 is a cat
# Loaded... 💃 Image 246 is a dog
# Loaded... 💃 Image 247 is a cat
# Loaded... 💃 Image 248 is a dog
# Loaded... 💃 Image 249 is a cat
# Loaded... 💃 Image 250 is a dog
# Loaded... 💃 Image 251 is a dog
# Loaded... 💃 Image 252 is a cat
# Loaded... 💃 Image 253 is a cat
# Loaded... 💃 Image 254 is a cat
# Loaded... 💃 Image 255 is a cat
# Loaded... 💃 Image 256 is a cat
# Loaded... 💃 Image 257 is a dog
# Loaded... 💃 Image 258 is a cat
# Loaded... 💃 Image 259 is a cat
# Loaded... 💃 Image 260 is a cat
# Loaded... 💃 Image 261 is a cat
# Loaded... 💃 Image 262 is a dog
# Loaded... 💃 Image 263 is a cat
# Loaded... 💃 Image 264 is a dog
# Loaded... 💃 Image 265 is a cat
# Loaded... 💃 Image 266 is a dog
# Loaded... 💃 Image 267 is a cat
# Loaded... 💃 Image 268 is a cat
# Loaded... 💃 Image 269 is a dog
# Loaded... 💃 Image 270 is a dog
# Loaded... 💃 Image 271 is a cat
# Loaded... 💃 Image 272 is a dog
# Loaded... 💃 Image 273 is a cat
# Loaded... 💃 Image 274 is a dog
# Loaded... 💃 Image 275 is a dog
# Loaded... 💃 Image 276 is a cat
# Loaded... 💃 Image 277 is a dog
# Loaded... 💃 Image 278 is a dog
# Loaded... 💃 Image 279 is a dog
# Loaded... 💃 Image 280 is a cat
# Loaded... 💃 Image 281 is a cat
# Loaded... 💃 Image 282 is a cat
# Loaded... 💃 Image 283 is a dog
# Loaded... 💃 Image 284 is a cat
# Loaded... 💃 Image 285 is a dog
# Loaded... 💃 Image 286 is a dog
# Loaded... 💃 Image 287 is a cat
# Loaded... 💃 Image 288 is a dog
# Loaded... 💃 Image 289 is a dog
# Loaded... 💃 Image 290 is a cat
# Loaded... 💃 Image 291 is a cat
# Loaded... 💃 Image 292 is a cat
# Loaded... 💃 Image 293 is a cat
# Loaded... 💃 Image 294 is a cat
# Loaded... 💃 Image 295 is a dog
# Loaded... 💃 Image 296 is a cat
# Loaded... 💃 Image 297 is a dog
# Loaded... 💃 Image 298 is a dog
# Loaded... 💃 Image 299 is a cat
# Loaded... 💃 Image 300 is a dog
# Loaded... 💃 Image 301 is a dog
# Loaded... 💃 Image 302 is a dog
# Loaded... 💃 Image 303 is a dog
# Loaded... 💃 Image 304 is a cat
# Loaded... 💃 Image 305 is a dog
# Loaded... 💃 Image 306 is a dog
# Loaded... 💃 Image 307 is a cat
# Loaded... 💃 Image 308 is a cat
# Loaded... 💃 Image 309 is a cat
# Loaded... 💃 Image 310 is a dog
# Loaded... 💃 Image 311 is a dog
# Loaded... 💃 Image 312 is a dog
# Loaded... 💃 Image 313 is a cat
# Loaded... 💃 Image 314 is a dog
# Loaded... 💃 Image 315 is a dog
# Loaded... 💃 Image 316 is a dog
# Loaded... 💃 Image 317 is a cat
# Loaded... 💃 Image 318 is a cat
# Loaded... 💃 Image 319 is a cat
# Loaded... 💃 Image 320 is a dog
# Loaded... 💃 Image 321 is a dog
# Loaded... 💃 Image 322 is a cat
# Loaded... 💃 Image 323 is a cat
# Loaded... 💃 Image 324 is a cat
# Loaded... 💃 Image 325 is a dog
# Loaded... 💃 Image 326 is a cat
# Loaded... 💃 Image 327 is a dog
# Loaded... 💃 Image 328 is a cat
# Loaded... 💃 Image 329 is a dog
# Loaded... 💃 Image 330 is a dog
# Loaded... 💃 Image 331 is a dog
# Loaded... 💃 Image 332 is a cat
# Loaded... 💃 Image 333 is a dog
# Loaded... 💃 Image 334 is a dog
# Loaded... 💃 Image 335 is a cat
# Loaded... 💃 Image 336 is a dog
# Loaded... 💃 Image 337 is a cat
# Loaded... 💃 Image 338 is a dog
# Loaded... 💃 Image 339 is a cat
# Loaded... 💃 Image 340 is a cat
# Loaded... 💃 Image 341 is a dog
# Loaded... 💃 Image 342 is a dog
# Loaded... 💃 Image 343 is a cat
# Loaded... 💃 Image 344 is a dog
# Loaded... 💃 Image 345 is a dog
# Loaded... 💃 Image 346 is a cat
# Loaded... 💃 Image 347 is a dog
# Loaded... 💃 Image 348 is a dog
# Loaded... 💃 Image 349 is a cat
# Loaded... 💃 Image 350 is a dog
# Loaded... 💃 Image 351 is a cat
# Loaded... 💃 Image 352 is a dog
# Loaded... 💃 Image 353 is a dog
# Loaded... 💃 Image 354 is a dog
# Loaded... 💃 Image 355 is a dog
# Loaded... 💃 Image 356 is a cat
# Loaded... 💃 Image 357 is a dog
# Loaded... 💃 Image 358 is a cat
# Loaded... 💃 Image 359 is a dog
# Loaded... 💃 Image 360 is a cat
# Loaded... 💃 Image 361 is a dog
# Loaded... 💃 Image 362 is a dog
# Loaded... 💃 Image 363 is a dog
# Loaded... 💃 Image 364 is a cat
# Loaded... 💃 Image 365 is a dog
# Loaded... 💃 Image 366 is a cat
# Loaded... 💃 Image 367 is a cat
# Loaded... 💃 Image 368 is a cat
# Loaded... 💃 Image 369 is a dog
# Loaded... 💃 Image 370 is a cat
# Loaded... 💃 Image 371 is a cat
# Loaded... 💃 Image 372 is a dog
# Loaded... 💃 Image 373 is a dog
# Loaded... 💃 Image 374 is a dog
# Loaded... 💃 Image 375 is a cat
# Loaded... 💃 Image 376 is a cat
# Loaded... 💃 Image 377 is a dog
# Loaded... 💃 Image 378 is a dog
# Loaded... 💃 Image 379 is a dog
# Loaded... 💃 Image 380 is a cat
# Loaded... 💃 Image 381 is a dog
# Loaded... 💃 Image 382 is a dog
# Loaded... 💃 Image 383 is a cat
# Loaded... 💃 Image 384 is a cat
# Loaded... 💃 Image 385 is a cat
# Loaded... 💃 Image 386 is a cat
# Loaded... 💃 Image 387 is a dog
# Loaded... 💃 Image 388 is a dog
# Loaded... 💃 Image 389 is a dog
# Loaded... 💃 Image 390 is a dog
# Loaded... 💃 Image 391 is a dog
# Loaded... 💃 Image 392 is a cat
# Loaded... 💃 Image 393 is a cat
# Loaded... 💃 Image 394 is a cat
# Loaded... 💃 Image 395 is a cat
# Loaded... 💃 Image 396 is a dog
# Loaded... 💃 Image 397 is a cat
# Loaded... 💃 Image 398 is a dog
# Loaded... 💃 Image 399 is a cat
# Loaded... 💃 Image 400 is a cat
# Loaded... 💃 Image 401 is a cat
# Loaded... 💃 Image 402 is a dog
# Loaded... 💃 Image 403 is a cat
# Loaded... 💃 Image 404 is a dog
# Loaded... 💃 Image 405 is a dog
# Loaded... 💃 Image 406 is a cat
# Loaded... 💃 Image 407 is a cat
# Loaded... 💃 Image 408 is a dog
# Loaded... 💃 Image 409 is a cat
# Loaded... 💃 Image 410 is a dog
# Loaded... 💃 Image 411 is a dog
# Loaded... 💃 Image 412 is a cat
# Loaded... 💃 Image 413 is a dog
# Loaded... 💃 Image 414 is a cat
# Loaded... 💃 Image 415 is a cat
# Loaded... 💃 Image 416 is a cat
# Loaded... 💃 Image 417 is a cat
# Loaded... 💃 Image 418 is a cat
# Loaded... 💃 Image 419 is a cat
# Loaded... 💃 Image 420 is a cat
# Loaded... 💃 Image 421 is a cat
# Loaded... 💃 Image 422 is a cat
# Loaded... 💃 Image 423 is a cat
# Loaded... 💃 Image 424 is a cat
# Loaded... 💃 Image 425 is a dog
# Loaded... 💃 Image 426 is a cat
# Loaded... 💃 Image 427 is a dog
# Loaded... 💃 Image 428 is a cat
# Loaded... 💃 Image 429 is a cat
# Loaded... 💃 Image 430 is a cat
# Loaded... 💃 Image 431 is a dog
# Loaded... 💃 Image 432 is a dog
# Loaded... 💃 Image 433 is a dog
# Loaded... 💃 Image 434 is a cat
# Loaded... 💃 Image 435 is a cat
# Loaded... 💃 Image 436 is a dog
# Loaded... 💃 Image 437 is a dog
# Loaded... 💃 Image 438 is a dog
# Loaded... 💃 Image 439 is a dog
# Loaded... 💃 Image 440 is a dog
# Loaded... 💃 Image 441 is a cat
# Loaded... 💃 Image 442 is a cat
# Loaded... 💃 Image 443 is a dog
# Loaded... 💃 Image 444 is a cat
# Loaded... 💃 Image 445 is a cat
# Loaded... 💃 Image 446 is a cat
# Loaded... 💃 Image 447 is a dog
# Loaded... 💃 Image 448 is a dog
# Loaded... 💃 Image 449 is a cat
# Loaded... 💃 Image 450 is a dog
# Loaded... 💃 Image 451 is a cat
# Loaded... 💃 Image 452 is a cat
# Loaded... 💃 Image 453 is a cat
# Loaded... 💃 Image 454 is a dog
# Loaded... 💃 Image 455 is a dog
# Loaded... 💃 Image 456 is a cat
# Loaded... 💃 Image 457 is a dog
# Loaded... 💃 Image 458 is a dog
# Loaded... 💃 Image 459 is a cat
# Loaded... 💃 Image 460 is a cat
# Loaded... 💃 Image 461 is a dog
# Loaded... 💃 Image 462 is a cat
# Loaded... 💃 Image 463 is a cat
# Loaded... 💃 Image 464 is a dog
# Loaded... 💃 Image 465 is a dog
# Loaded... 💃 Image 466 is a dog
# Loaded... 💃 Image 467 is a dog
# Loaded... 💃 Image 468 is a cat
# Loaded... 💃 Image 469 is a cat
# Loaded... 💃 Image 470 is a cat
# Loaded... 💃 Image 471 is a cat
# Loaded... 💃 Image 472 is a cat
# Loaded... 💃 Image 473 is a dog
# Loaded... 💃 Image 474 is a cat
# Loaded... 💃 Image 475 is a dog
# Loaded... 💃 Image 476 is a cat
# Loaded... 💃 Image 477 is a dog
# Loaded... 💃 Image 478 is a dog
# Loaded... 💃 Image 479 is a dog
# Loaded... 💃 Image 480 is a dog
# Loaded... 💃 Image 481 is a dog
# Loaded... 💃 Image 482 is a dog
# Loaded... 💃 Image 483 is a cat
# Loaded... 💃 Image 484 is a dog
# Loaded... 💃 Image 485 is a cat
# Loaded... 💃 Image 486 is a dog
# Loaded... 💃 Image 487 is a cat
# Loaded... 💃 Image 488 is a cat
# Loaded... 💃 Image 489 is a cat
# Loaded... 💃 Image 490 is a cat
# Loaded... 💃 Image 491 is a dog
# Loaded... 💃 Image 492 is a dog
# Loaded... 💃 Image 493 is a cat
# Loaded... 💃 Image 494 is a cat
# Loaded... 💃 Image 495 is a cat
# Loaded... 💃 Image 496 is a dog
# Loaded... 💃 Image 497 is a dog
# Loaded... 💃 Image 498 is a dog
# Loaded... 💃 Image 499 is a dog
# Loaded... 💃 Image 500 is a dog
# Loaded... 💃 Image 501 is a dog
# Loaded... 💃 Image 502 is a cat
# Loaded... 💃 Image 503 is a cat
# Loaded... 💃 Image 504 is a cat
# Loaded... 💃 Image 505 is a dog
# Loaded... 💃 Image 506 is a cat
# Loaded... 💃 Image 507 is a dog
# Loaded... 💃 Image 508 is a dog
# Loaded... 💃 Image 509 is a cat
# Loaded... 💃 Image 510 is a dog
# Loaded... 💃 Image 511 is a dog
# Loaded... 💃 Image 512 is a cat
# Loaded... 💃 Image 513 is a cat
# Loaded... 💃 Image 514 is a cat
# Loaded... 💃 Image 515 is a cat
# Loaded... 💃 Image 516 is a cat
# Loaded... 💃 Image 517 is a cat
# Loaded... 💃 Image 518 is a dog
# Loaded... 💃 Image 519 is a dog
# Loaded... 💃 Image 520 is a dog
# Loaded... 💃 Image 521 is a dog
# Loaded... 💃 Image 522 is a dog
# Loaded... 💃 Image 523 is a cat
# Loaded... 💃 Image 524 is a cat
# Loaded... 💃 Image 525 is a cat
# Loaded... 💃 Image 526 is a cat
# Loaded... 💃 Image 527 is a cat
# Loaded... 💃 Image 528 is a dog
# Loaded... 💃 Image 529 is a cat
# Loaded... 💃 Image 530 is a dog
# Loaded... 💃 Image 531 is a dog
# Loaded... 💃 Image 532 is a dog
# Loaded... 💃 Image 533 is a cat
# Loaded... 💃 Image 534 is a dog
# Loaded... 💃 Image 535 is a dog
# Loaded... 💃 Image 536 is a cat
# Loaded... 💃 Image 537 is a dog
# Loaded... 💃 Image 538 is a cat
# Loaded... 💃 Image 539 is a dog
# Loaded... 💃 Image 540 is a dog
# Loaded... 💃 Image 541 is a dog
# Loaded... 💃 Image 542 is a dog
# Loaded... 💃 Image 543 is a dog
# Loaded... 💃 Image 544 is a dog
# Loaded... 💃 Image 545 is a cat
# Loaded... 💃 Image 546 is a cat
# Loaded... 💃 Image 547 is a dog
# Loaded... 💃 Image 548 is a cat
# Loaded... 💃 Image 549 is a dog
# Loaded... 💃 Image 550 is a dog
# Loaded... 💃 Image 551 is a cat
# Loaded... 💃 Image 552 is a cat
# Loaded... 💃 Image 553 is a dog
# Loaded... 💃 Image 554 is a dog
# Loaded... 💃 Image 555 is a dog
# Loaded... 💃 Image 556 is a dog
# Loaded... 💃 Image 557 is a dog
# Loaded... 💃 Image 558 is a cat
# Loaded... 💃 Image 559 is a dog
# Loaded... 💃 Image 560 is a dog
# Loaded... 💃 Image 561 is a cat
# Loaded... 💃 Image 562 is a dog
# Loaded... 💃 Image 563 is a dog
# Loaded... 💃 Image 564 is a cat
# Loaded... 💃 Image 565 is a cat
# Loaded... 💃 Image 566 is a cat
# Loaded... 💃 Image 567 is a cat
# Loaded... 💃 Image 568 is a dog
# Loaded... 💃 Image 569 is a dog
# Loaded... 💃 Image 570 is a cat
# Loaded... 💃 Image 571 is a dog
# Loaded... 💃 Image 572 is a dog
# Loaded... 💃 Image 573 is a cat
# Loaded... 💃 Image 574 is a dog
# Loaded... 💃 Image 575 is a cat
# Loaded... 💃 Image 576 is a cat
# Loaded... 💃 Image 577 is a cat
# Loaded... 💃 Image 578 is a cat
# Loaded... 💃 Image 579 is a cat
# Loaded... 💃 Image 580 is a dog
# Loaded... 💃 Image 581 is a dog
# Loaded... 💃 Image 582 is a cat
# Loaded... 💃 Image 583 is a cat
# Loaded... 💃 Image 584 is a dog
# Loaded... 💃 Image 585 is a cat
# Loaded... 💃 Image 586 is a cat
# Loaded... 💃 Image 587 is a dog
# Loaded... 💃 Image 588 is a dog
# Loaded... 💃 Image 589 is a dog
# Loaded... 💃 Image 590 is a dog
# Loaded... 💃 Image 591 is a cat
# Loaded... 💃 Image 592 is a cat
# Loaded... 💃 Image 593 is a cat
# Loaded... 💃 Image 594 is a dog
# Loaded... 💃 Image 595 is a cat
# Loaded... 💃 Image 596 is a dog
# Loaded... 💃 Image 597 is a dog
# Loaded... 💃 Image 598 is a dog
# Loaded... 💃 Image 599 is a cat
# Loaded... 💃 Image 600 is a cat
# Loaded... 💃 Image 601 is a dog
# Loaded... 💃 Image 602 is a cat
# Loaded... 💃 Image 603 is a dog
# Loaded... 💃 Image 604 is a dog
# Loaded... 💃 Image 605 is a cat
# Loaded... 💃 Image 606 is a cat
# Loaded... 💃 Image 607 is a cat
# Loaded... 💃 Image 608 is a dog
# Loaded... 💃 Image 609 is a dog
# Loaded... 💃 Image 610 is a cat
# Loaded... 💃 Image 611 is a cat
# Loaded... 💃 Image 612 is a cat
# Loaded... 💃 Image 613 is a dog
# Loaded... 💃 Image 614 is a dog
# Loaded... 💃 Image 615 is a cat
# Loaded... 💃 Image 616 is a dog
# Loaded... 💃 Image 617 is a dog
# Loaded... 💃 Image 618 is a cat
# Loaded... 💃 Image 619 is a cat
# Loaded... 💃 Image 620 is a dog
# Loaded... 💃 Image 621 is a dog
# Loaded... 💃 Image 622 is a dog
# Loaded... 💃 Image 623 is a dog
# Loaded... 💃 Image 624 is a cat
# Loaded... 💃 Image 625 is a dog
# Loaded... 💃 Image 626 is a cat
# Loaded... 💃 Image 627 is a dog
# Loaded... 💃 Image 628 is a cat
# Loaded... 💃 Image 629 is a cat
# Loaded... 💃 Image 630 is a cat
# Loaded... 💃 Image 631 is a dog
# Loaded... 💃 Image 632 is a cat
# Loaded... 💃 Image 633 is a dog
# Loaded... 💃 Image 634 is a cat
# Loaded... 💃 Image 635 is a cat
# Loaded... 💃 Image 636 is a dog
# Loaded... 💃 Image 637 is a dog
# Loaded... 💃 Image 638 is a dog
# Loaded... 💃 Image 639 is a dog
# Loaded... 💃 Image 640 is a cat
# Loaded... 💃 Image 641 is a cat
# Loaded... 💃 Image 642 is a dog
# Loaded... 💃 Image 643 is a dog
# Loaded... 💃 Image 644 is a dog
# Loaded... 💃 Image 645 is a cat
# Loaded... 💃 Image 646 is a cat
# Loaded... 💃 Image 647 is a dog
# Loaded... 💃 Image 648 is a cat
# Loaded... 💃 Image 649 is a cat
# Loaded... 💃 Image 650 is a dog
# Loaded... 💃 Image 651 is a cat
# Loaded... 💃 Image 652 is a dog
# Loaded... 💃 Image 653 is a dog
# Loaded... 💃 Image 654 is a dog
# Loaded... 💃 Image 655 is a dog
# Loaded... 💃 Image 656 is a dog
# Loaded... 💃 Image 657 is a dog
# Loaded... 💃 Image 658 is a dog
# Loaded... 💃 Image 659 is a dog
# Loaded... 💃 Image 660 is a dog
# Loaded... 💃 Image 661 is a dog
# Loaded... 💃 Image 662 is a dog
# Loaded... 💃 Image 663 is a cat
# Loaded... 💃 Image 664 is a dog
# Loaded... 💃 Image 665 is a cat
# Loaded... 💃 Image 666 is a dog
# Loaded... 💃 Image 667 is a cat
# Loaded... 💃 Image 668 is a dog
# Loaded... 💃 Image 669 is a cat
# Loaded... 💃 Image 670 is a cat
# Loaded... 💃 Image 671 is a cat
# Loaded... 💃 Image 672 is a dog
# Loaded... 💃 Image 673 is a cat
# Loaded... 💃 Image 674 is a cat
# Loaded... 💃 Image 675 is a dog
# Loaded... 💃 Image 676 is a cat
# Loaded... 💃 Image 677 is a dog
# Loaded... 💃 Image 678 is a dog
# Loaded... 💃 Image 679 is a dog
# Loaded... 💃 Image 680 is a dog
# Loaded... 💃 Image 681 is a cat
# Loaded... 💃 Image 682 is a dog
# Loaded... 💃 Image 683 is a dog
# Loaded... 💃 Image 684 is a dog
# Loaded... 💃 Image 685 is a cat
# Loaded... 💃 Image 686 is a cat
# Loaded... 💃 Image 687 is a dog
# Loaded... 💃 Image 688 is a cat
# Loaded... 💃 Image 689 is a cat
# Loaded... 💃 Image 690 is a cat
# Loaded... 💃 Image 691 is a cat
# Loaded... 💃 Image 692 is a cat
# Loaded... 💃 Image 693 is a cat
# Loaded... 💃 Image 694 is a cat
# Loaded... 💃 Image 695 is a dog
# Loaded... 💃 Image 696 is a cat
# Loaded... 💃 Image 697 is a cat
# Loaded... 💃 Image 698 is a cat
# Loaded... 💃 Image 699 is a cat
# Loaded... 💃 Image 700 is a cat
# Loaded... 💃 Image 701 is a cat
# Loaded... 💃 Image 702 is a cat
# Loaded... 💃 Image 703 is a cat
# Loaded... 💃 Image 704 is a dog
# Loaded... 💃 Image 705 is a dog
# Loaded... 💃 Image 706 is a cat
# Loaded... 💃 Image 707 is a dog
# Loaded... 💃 Image 708 is a dog
# Loaded... 💃 Image 709 is a cat
# Loaded... 💃 Image 710 is a cat
# Loaded... 💃 Image 711 is a cat
# Loaded... 💃 Image 712 is a cat
# Loaded... 💃 Image 713 is a cat
# Loaded... 💃 Image 714 is a cat
# Loaded... 💃 Image 715 is a dog
# Loaded... 💃 Image 716 is a dog
# Loaded... 💃 Image 717 is a dog
# Loaded... 💃 Image 718 is a dog
# Loaded... 💃 Image 719 is a dog
# Loaded... 💃 Image 720 is a dog
# Loaded... 💃 Image 721 is a dog
# Loaded... 💃 Image 722 is a dog
# Loaded... 💃 Image 723 is a cat
# Loaded... 💃 Image 724 is a dog
# Loaded... 💃 Image 725 is a cat
# Loaded... 💃 Image 726 is a cat
# Loaded... 💃 Image 727 is a cat
# Loaded... 💃 Image 728 is a cat
# Loaded... 💃 Image 729 is a dog
# Loaded... 💃 Image 730 is a dog
# Loaded... 💃 Image 731 is a dog
# Loaded... 💃 Image 732 is a cat
# Loaded... 💃 Image 733 is a dog
# Loaded... 💃 Image 734 is a dog
# Loaded... 💃 Image 735 is a dog
# Loaded... 💃 Image 736 is a cat
# Loaded... 💃 Image 737 is a cat
# Loaded... 💃 Image 738 is a cat
# Loaded... 💃 Image 739 is a cat
# Loaded... 💃 Image 740 is a cat
# Loaded... 💃 Image 741 is a dog
# Loaded... 💃 Image 742 is a cat
# Loaded... 💃 Image 743 is a dog
# Loaded... 💃 Image 744 is a cat
# Loaded... 💃 Image 745 is a cat
# Loaded... 💃 Image 746 is a dog
# Loaded... 💃 Image 747 is a cat
# Loaded... 💃 Image 748 is a dog
# Loaded... 💃 Image 749 is a dog
# Loaded... 💃 Image 750 is a cat
# Loaded... 💃 Image 751 is a dog
# Loaded... 💃 Image 752 is a dog
# Loaded... 💃 Image 753 is a dog
# Loaded... 💃 Image 754 is a cat
# Loaded... 💃 Image 755 is a dog
# Loaded... 💃 Image 756 is a dog
# Loaded... 💃 Image 757 is a cat
# Loaded... 💃 Image 758 is a dog
# Loaded... 💃 Image 759 is a cat
# Loaded... 💃 Image 760 is a cat
# Loaded... 💃 Image 761 is a dog
# Loaded... 💃 Image 762 is a cat
# Loaded... 💃 Image 763 is a cat
# Loaded... 💃 Image 764 is a cat
# Loaded... 💃 Image 765 is a dog
# Loaded... 💃 Image 766 is a cat
# Loaded... 💃 Image 767 is a cat
# Loaded... 💃 Image 768 is a dog
# Loaded... 💃 Image 769 is a dog
# Loaded... 💃 Image 770 is a cat
# Loaded... 💃 Image 771 is a cat
# Loaded... 💃 Image 772 is a dog
# Loaded... 💃 Image 773 is a dog
# Loaded... 💃 Image 774 is a dog
# Loaded... 💃 Image 775 is a cat
# Loaded... 💃 Image 776 is a dog
# Loaded... 💃 Image 777 is a cat
# Loaded... 💃 Image 778 is a cat
# Loaded... 💃 Image 779 is a cat
# Loaded... 💃 Image 780 is a dog
# Loaded... 💃 Image 781 is a dog
# Loaded... 💃 Image 782 is a dog
# Loaded... 💃 Image 783 is a cat
# Loaded... 💃 Image 784 is a dog
# Loaded... 💃 Image 785 is a dog
# Loaded... 💃 Image 786 is a cat
# Loaded... 💃 Image 787 is a dog
# Loaded... 💃 Image 788 is a dog
# Loaded... 💃 Image 789 is a dog
# Loaded... 💃 Image 790 is a cat
# Loaded... 💃 Image 791 is a dog
# Loaded... 💃 Image 792 is a dog
# Loaded... 💃 Image 793 is a cat
# Loaded... 💃 Image 794 is a dog
# Loaded... 💃 Image 795 is a dog
# Loaded... 💃 Image 796 is a cat
# Loaded... 💃 Image 797 is a cat
# Loaded... 💃 Image 798 is a dog
# Loaded... 💃 Image 799 is a dog
# Loaded... 💃 Image 800 is a dog
# Loaded... 💃 Image 801 is a cat
# Loaded... 💃 Image 802 is a cat
# Loaded... 💃 Image 803 is a cat
# Loaded... 💃 Image 804 is a cat
# Loaded... 💃 Image 805 is a cat
# Loaded... 💃 Image 806 is a dog
# Loaded... 💃 Image 807 is a dog
# Loaded... 💃 Image 808 is a cat
# Loaded... 💃 Image 809 is a cat
# Loaded... 💃 Image 810 is a cat
# Loaded... 💃 Image 811 is a dog
# Loaded... 💃 Image 812 is a cat
# Loaded... 💃 Image 813 is a cat
# Loaded... 💃 Image 814 is a dog
# Loaded... 💃 Image 815 is a dog
# Loaded... 💃 Image 816 is a dog
# Loaded... 💃 Image 817 is a cat
# Loaded... 💃 Image 818 is a dog
# Loaded... 💃 Image 819 is a dog
# Loaded... 💃 Image 820 is a cat
# Loaded... 💃 Image 821 is a dog
# Loaded... 💃 Image 822 is a cat
# Loaded... 💃 Image 823 is a dog
# Loaded... 💃 Image 824 is a dog
# Loaded... 💃 Image 825 is a cat
# Loaded... 💃 Image 826 is a cat
# Loaded... 💃 Image 827 is a cat
# Loaded... 💃 Image 828 is a cat
# Loaded... 💃 Image 829 is a dog
# Loaded... 💃 Image 830 is a dog
# Loaded... 💃 Image 831 is a cat
# Loaded... 💃 Image 832 is a cat
# Loaded... 💃 Image 833 is a cat
# Loaded... 💃 Image 834 is a dog
# Loaded... 💃 Image 835 is a cat
# Loaded... 💃 Image 836 is a cat
# Loaded... 💃 Image 837 is a cat
# Loaded... 💃 Image 838 is a cat
# Loaded... 💃 Image 839 is a dog
# Loaded... 💃 Image 840 is a cat
# Loaded... 💃 Image 841 is a dog
# Loaded... 💃 Image 842 is a dog
# Loaded... 💃 Image 843 is a cat
# Loaded... 💃 Image 844 is a dog
# Loaded... 💃 Image 845 is a cat
# Loaded... 💃 Image 846 is a dog
# Loaded... 💃 Image 847 is a cat
# Loaded... 💃 Image 848 is a dog
# Loaded... 💃 Image 849 is a dog
# Loaded... 💃 Image 850 is a dog
# Loaded... 💃 Image 851 is a dog
# Loaded... 💃 Image 852 is a dog
# Loaded... 💃 Image 853 is a dog
# Loaded... 💃 Image 854 is a dog
# Loaded... 💃 Image 855 is a dog
# Loaded... 💃 Image 856 is a dog
# Loaded... 💃 Image 857 is a dog
# Loaded... 💃 Image 858 is a dog
# Loaded... 💃 Image 859 is a cat
# Loaded... 💃 Image 860 is a dog
# Loaded... 💃 Image 861 is a cat
# Loaded... 💃 Image 862 is a cat
# Loaded... 💃 Image 863 is a cat
# Loaded... 💃 Image 864 is a dog
# Loaded... 💃 Image 865 is a dog
# Loaded... 💃 Image 866 is a cat
# Loaded... 💃 Image 867 is a dog
# Loaded... 💃 Image 868 is a cat
# Loaded... 💃 Image 869 is a dog
# Loaded... 💃 Image 870 is a dog
# Loaded... 💃 Image 871 is a dog
# Loaded... 💃 Image 872 is a dog
# Loaded... 💃 Image 873 is a dog
# Loaded... 💃 Image 874 is a dog
# Loaded... 💃 Image 875 is a dog
# Loaded... 💃 Image 876 is a cat
# Loaded... 💃 Image 877 is a cat
# Loaded... 💃 Image 878 is a dog
# Loaded... 💃 Image 879 is a dog
# Loaded... 💃 Image 880 is a cat
# Loaded... 💃 Image 881 is a cat
# Loaded... 💃 Image 882 is a cat
# Loaded... 💃 Image 883 is a dog
# Loaded... 💃 Image 884 is a dog
# Loaded... 💃 Image 885 is a cat
# Loaded... 💃 Image 886 is a dog
# Loaded... 💃 Image 887 is a dog
# Loaded... 💃 Image 888 is a dog
# Loaded... 💃 Image 889 is a dog
# Loaded... 💃 Image 890 is a dog
# Loaded... 💃 Image 891 is a dog
# Loaded... 💃 Image 892 is a cat
# Loaded... 💃 Image 893 is a dog
# Loaded... 💃 Image 894 is a dog
# Loaded... 💃 Image 895 is a dog
# Loaded... 💃 Image 896 is a cat
# Loaded... 💃 Image 897 is a cat
# Loaded... 💃 Image 898 is a cat
# Loaded... 💃 Image 899 is a dog
# Loaded... 💃 Image 900 is a cat
# Loaded... 💃 Image 901 is a cat
# Loaded... 💃 Image 902 is a dog
# Loaded... 💃 Image 903 is a dog
# Loaded... 💃 Image 904 is a cat
# Loaded... 💃 Image 905 is a dog
# Loaded... 💃 Image 906 is a cat
# Loaded... 💃 Image 907 is a cat
# Loaded... 💃 Image 908 is a cat
# Loaded... 💃 Image 909 is a cat
# Loaded... 💃 Image 910 is a dog
# Loaded... 💃 Image 911 is a dog
# Loaded... 💃 Image 912 is a dog
# Loaded... 💃 Image 913 is a dog
# Loaded... 💃 Image 914 is a dog
# Loaded... 💃 Image 915 is a cat
# Loaded... 💃 Image 916 is a dog
# Loaded... 💃 Image 917 is a cat
# Loaded... 💃 Image 918 is a dog
# Loaded... 💃 Image 919 is a dog
# Loaded... 💃 Image 920 is a dog
# Loaded... 💃 Image 921 is a cat
# Loaded... 💃 Image 922 is a dog
# Loaded... 💃 Image 923 is a cat
# Loaded... 💃 Image 924 is a dog
# Loaded... 💃 Image 925 is a cat
# Loaded... 💃 Image 926 is a dog
# Loaded... 💃 Image 927 is a cat
# Loaded... 💃 Image 928 is a dog
# Loaded... 💃 Image 929 is a cat
# Loaded... 💃 Image 930 is a dog
# Loaded... 💃 Image 931 is a dog
# Loaded... 💃 Image 932 is a cat
# Loaded... 💃 Image 933 is a cat
# Loaded... 💃 Image 934 is a cat
# Loaded... 💃 Image 935 is a dog
# Loaded... 💃 Image 936 is a dog
# Loaded... 💃 Image 937 is a cat
# Loaded... 💃 Image 938 is a cat
# Loaded... 💃 Image 939 is a cat
# Loaded... 💃 Image 940 is a cat
# Loaded... 💃 Image 941 is a dog
# Loaded... 💃 Image 942 is a dog
# Loaded... 💃 Image 943 is a dog
# Loaded... 💃 Image 944 is a cat
# Loaded... 💃 Image 945 is a cat
# Loaded... 💃 Image 946 is a cat
# Loaded... 💃 Image 947 is a cat
# Loaded... 💃 Image 948 is a cat
# Loaded... 💃 Image 949 is a cat
# Loaded... 💃 Image 950 is a dog
# Loaded... 💃 Image 951 is a cat
# Loaded... 💃 Image 952 is a dog
# Loaded... 💃 Image 953 is a cat
# Loaded... 💃 Image 954 is a dog
# Loaded... 💃 Image 955 is a dog
# Loaded... 💃 Image 956 is a cat
# Loaded... 💃 Image 957 is a cat
# Loaded... 💃 Image 958 is a dog
# Loaded... 💃 Image 959 is a dog
# Loaded... 💃 Image 960 is a cat
# Loaded... 💃 Image 961 is a dog
# Loaded... 💃 Image 962 is a cat
# Loaded... 💃 Image 963 is a cat
# Loaded... 💃 Image 964 is a cat
# Loaded... 💃 Image 965 is a dog
# Loaded... 💃 Image 966 is a cat
# Loaded... 💃 Image 967 is a dog
# Loaded... 💃 Image 968 is a dog
# Loaded... 💃 Image 969 is a dog
# Loaded... 💃 Image 970 is a dog
# Loaded... 💃 Image 971 is a cat
# Loaded... 💃 Image 972 is a dog
# Loaded... 💃 Image 973 is a dog
# Loaded... 💃 Image 974 is a cat
# Loaded... 💃 Image 975 is a dog
# Loaded... 💃 Image 976 is a dog
# Loaded... 💃 Image 977 is a dog
# Loaded... 💃 Image 978 is a cat
# Loaded... 💃 Image 979 is a dog
# Loaded... 💃 Image 980 is a dog
# Loaded... 💃 Image 981 is a cat
# Loaded... 💃 Image 982 is a dog
# Loaded... 💃 Image 983 is a cat
# Loaded... 💃 Image 984 is a cat
# Loaded... 💃 Image 985 is a dog
# Loaded... 💃 Image 986 is a dog
# Loaded... 💃 Image 987 is a cat
# Loaded... 💃 Image 988 is a dog
# Loaded... 💃 Image 989 is a cat
# Loaded... 💃 Image 990 is a cat
# Loaded... 💃 Image 991 is a dog
# Loaded... 💃 Image 992 is a cat
# Loaded... 💃 Image 993 is a cat
# Loaded... 💃 Image 994 is a dog
# Loaded... 💃 Image 995 is a cat
# Loaded... 💃 Image 996 is a cat
# Loaded... 💃 Image 997 is a dog
# Loaded... 💃 Image 998 is a dog
# Loaded... 💃 Image 999 is a dog
# Loaded... 💃 Image 1000 is a dog
# Loaded... 💃 Image 1001 is a cat
# Loaded... 💃 Image 1002 is a cat
# Loaded... 💃 Image 1003 is a cat
# Loaded... 💃 Image 1004 is a cat
# Loaded... 💃 Image 1005 is a dog
# Loaded... 💃 Image 1006 is a dog
# Loaded... 💃 Image 1007 is a cat
# Loaded... 💃 Image 1008 is a cat
# Loaded... 💃 Image 1009 is a cat
# Loaded... 💃 Image 1010 is a cat
# Loaded... 💃 Image 1011 is a cat
# Loaded... 💃 Image 1012 is a dog
# Loaded... 💃 Image 1013 is a cat
# Loaded... 💃 Image 1014 is a cat
# Loaded... 💃 Image 1015 is a cat
# Loaded... 💃 Image 1016 is a cat
# Loaded... 💃 Image 1017 is a dog
# Loaded... 💃 Image 1018 is a dog
# Loaded... 💃 Image 1019 is a cat
# Loaded... 💃 Image 1020 is a dog
# Loaded... 💃 Image 1021 is a dog
# Loaded... 💃 Image 1022 is a dog
# Loaded... 💃 Image 1023 is a dog
# Loaded... 💃 Image 1024 is a dog
# Loaded... 💃 Image 1025 is a cat
# Loaded... 💃 Image 1026 is a cat
# Loaded... 💃 Image 1027 is a dog
# Loaded... 💃 Image 1028 is a dog
# Loaded... 💃 Image 1029 is a cat
# Loaded... 💃 Image 1030 is a cat
# Loaded... 💃 Image 1031 is a cat
# Loaded... 💃 Image 1032 is a cat
# Loaded... 💃 Image 1033 is a cat
# Loaded... 💃 Image 1034 is a cat
# Loaded... 💃 Image 1035 is a dog
# Loaded... 💃 Image 1036 is a cat
# Loaded... 💃 Image 1037 is a dog
# Loaded... 💃 Image 1038 is a cat
# Loaded... 💃 Image 1039 is a cat
# Loaded... 💃 Image 1040 is a cat
# Loaded... 💃 Image 1041 is a dog
# Loaded... 💃 Image 1042 is a cat
# Loaded... 💃 Image 1043 is a dog
# Loaded... 💃 Image 1044 is a cat
# Loaded... 💃 Image 1045 is a dog
# Loaded... 💃 Image 1046 is a dog
# Loaded... 💃 Image 1047 is a cat
# Loaded... 💃 Image 1048 is a dog
# Loaded... 💃 Image 1049 is a dog
# Loaded... 💃 Image 1050 is a cat
# Loaded... 💃 Image 1051 is a dog
# Loaded... 💃 Image 1052 is a cat
# Loaded... 💃 Image 1053 is a dog
# Loaded... 💃 Image 1054 is a cat
# Loaded... 💃 Image 1055 is a dog
# Loaded... 💃 Image 1056 is a cat
# Loaded... 💃 Image 1057 is a cat
# Loaded... 💃 Image 1058 is a cat
# Loaded... 💃 Image 1059 is a dog
# Loaded... 💃 Image 1060 is a dog
# Loaded... 💃 Image 1061 is a dog
# Loaded... 💃 Image 1062 is a dog
# Loaded... 💃 Image 1063 is a dog
# Loaded... 💃 Image 1064 is a cat
# Loaded... 💃 Image 1065 is a dog
# Loaded... 💃 Image 1066 is a cat
# Loaded... 💃 Image 1067 is a dog
# Loaded... 💃 Image 1068 is a dog
# Loaded... 💃 Image 1069 is a dog
# Loaded... 💃 Image 1070 is a cat
# Loaded... 💃 Image 1071 is a dog
# Loaded... 💃 Image 1072 is a cat
# Loaded... 💃 Image 1073 is a dog
# Loaded... 💃 Image 1074 is a dog
# Loaded... 💃 Image 1075 is a dog
# Loaded... 💃 Image 1076 is a dog
# Loaded... 💃 Image 1077 is a cat
# Loaded... 💃 Image 1078 is a cat
# Loaded... 💃 Image 1079 is a dog
# Loaded... 💃 Image 1080 is a dog
# Loaded... 💃 Image 1081 is a dog
# Loaded... 💃 Image 1082 is a dog
# Loaded... 💃 Image 1083 is a dog
# Loaded... 💃 Image 1084 is a cat
# Loaded... 💃 Image 1085 is a dog
# Loaded... 💃 Image 1086 is a dog
# Loaded... 💃 Image 1087 is a cat
# Loaded... 💃 Image 1088 is a dog
# Loaded... 💃 Image 1089 is a cat
# Loaded... 💃 Image 1090 is a dog
# Loaded... 💃 Image 1091 is a cat
# Loaded... 💃 Image 1092 is a cat
# Loaded... 💃 Image 1093 is a cat
# Loaded... 💃 Image 1094 is a cat
# Loaded... 💃 Image 1095 is a dog
# Loaded... 💃 Image 1096 is a dog
# Loaded... 💃 Image 1097 is a dog
# Loaded... 💃 Image 1098 is a cat
# Loaded... 💃 Image 1099 is a dog
# Loaded... 💃 Image 1100 is a dog
# Loaded... 💃 Image 1101 is a cat
# Loaded... 💃 Image 1102 is a cat
# Loaded... 💃 Image 1103 is a dog
# Loaded... 💃 Image 1104 is a cat
# Loaded... 💃 Image 1105 is a cat
# Loaded... 💃 Image 1106 is a cat
# Loaded... 💃 Image 1107 is a dog
# Loaded... 💃 Image 1108 is a cat
# Loaded... 💃 Image 1109 is a cat
# Loaded... 💃 Image 1110 is a cat
# Loaded... 💃 Image 1111 is a cat
# Loaded... 💃 Image 1112 is a cat
# Loaded... 💃 Image 1113 is a dog
# Loaded... 💃 Image 1114 is a dog
# Loaded... 💃 Image 1115 is a cat
# Loaded... 💃 Image 1116 is a dog
# Loaded... 💃 Image 1117 is a cat
# Loaded... 💃 Image 1118 is a dog
# Loaded... 💃 Image 1119 is a dog
# Loaded... 💃 Image 1120 is a cat
# Loaded... 💃 Image 1121 is a dog
# Loaded... 💃 Image 1122 is a dog
# Loaded... 💃 Image 1123 is a cat
# Loaded... 💃 Image 1124 is a cat
# Loaded... 💃 Image 1125 is a dog
# Loaded... 💃 Image 1126 is a cat
# Loaded... 💃 Image 1127 is a dog
# Loaded... 💃 Image 1128 is a dog
# Loaded... 💃 Image 1129 is a cat
# Loaded... 💃 Image 1130 is a cat
# Loaded... 💃 Image 1131 is a cat
# Loaded... 💃 Image 1132 is a dog
# Loaded... 💃 Image 1133 is a dog
# Loaded... 💃 Image 1134 is a dog
# Loaded... 💃 Image 1135 is a dog
# Loaded... 💃 Image 1136 is a cat
# Loaded... 💃 Image 1137 is a dog
# Loaded... 💃 Image 1138 is a cat
# Loaded... 💃 Image 1139 is a dog
# Loaded... 💃 Image 1140 is a dog
# Loaded... 💃 Image 1141 is a dog
# Loaded... 💃 Image 1142 is a dog
# Loaded... 💃 Image 1143 is a cat
# Loaded... 💃 Image 1144 is a cat
# Loaded... 💃 Image 1145 is a dog
# Loaded... 💃 Image 1146 is a dog
# Loaded... 💃 Image 1147 is a dog
# Loaded... 💃 Image 1148 is a dog
# Loaded... 💃 Image 1149 is a dog
# Loaded... 💃 Image 1150 is a dog
# Loaded... 💃 Image 1151 is a cat
# Loaded... 💃 Image 1152 is a cat
# Loaded... 💃 Image 1153 is a cat
# Loaded... 💃 Image 1154 is a dog
# Loaded... 💃 Image 1155 is a dog
# Loaded... 💃 Image 1156 is a dog
# Loaded... 💃 Image 1157 is a dog
# Loaded... 💃 Image 1158 is a cat
# Loaded... 💃 Image 1159 is a cat
# Loaded... 💃 Image 1160 is a cat
# Loaded... 💃 Image 1161 is a cat
# Loaded... 💃 Image 1162 is a cat
# Loaded... 💃 Image 1163 is a cat
# Loaded... 💃 Image 1164 is a cat
# Loaded... 💃 Image 1165 is a cat
# Loaded... 💃 Image 1166 is a dog
# Loaded... 💃 Image 1167 is a cat
# Loaded... 💃 Image 1168 is a dog
# Loaded... 💃 Image 1169 is a cat
# Loaded... 💃 Image 1170 is a cat
# Loaded... 💃 Image 1171 is a dog
# Loaded... 💃 Image 1172 is a dog
# Loaded... 💃 Image 1173 is a dog
# Loaded... 💃 Image 1174 is a cat
# Loaded... 💃 Image 1175 is a dog
# Loaded... 💃 Image 1176 is a dog
# Loaded... 💃 Image 1177 is a dog
# Loaded... 💃 Image 1178 is a dog
# Loaded... 💃 Image 1179 is a cat
# Loaded... 💃 Image 1180 is a cat
# Loaded... 💃 Image 1181 is a dog
# Loaded... 💃 Image 1182 is a dog
# Loaded... 💃 Image 1183 is a dog
# Loaded... 💃 Image 1184 is a dog
# Loaded... 💃 Image 1185 is a dog
# Loaded... 💃 Image 1186 is a cat
# Loaded... 💃 Image 1187 is a cat
# Loaded... 💃 Image 1188 is a cat
# Loaded... 💃 Image 1189 is a dog
# Loaded... 💃 Image 1190 is a dog
# Loaded... 💃 Image 1191 is a cat
# Loaded... 💃 Image 1192 is a cat
# Loaded... 💃 Image 1193 is a dog
# Loaded... 💃 Image 1194 is a dog
# Loaded... 💃 Image 1195 is a cat
# Loaded... 💃 Image 1196 is a cat
# Loaded... 💃 Image 1197 is a dog
# Loaded... 💃 Image 1198 is a dog
# Loaded... 💃 Image 1199 is a cat
# Loaded... 💃 Image 1200 is a dog
# Loaded... 💃 Image 1201 is a cat
# Loaded... 💃 Image 1202 is a dog
# Loaded... 💃 Image 1203 is a dog
# Loaded... 💃 Image 1204 is a dog
# Loaded... 💃 Image 1205 is a dog
# Loaded... 💃 Image 1206 is a dog
# Loaded... 💃 Image 1207 is a cat
# Loaded... 💃 Image 1208 is a dog
# Loaded... 💃 Image 1209 is a dog
# Loaded... 💃 Image 1210 is a cat
# Loaded... 💃 Image 1211 is a cat
# Loaded... 💃 Image 1212 is a cat
# Loaded... 💃 Image 1213 is a dog
# Loaded... 💃 Image 1214 is a dog
# Loaded... 💃 Image 1215 is a cat
# Loaded... 💃 Image 1216 is a cat
# Loaded... 💃 Image 1217 is a cat
# Loaded... 💃 Image 1218 is a dog
# Loaded... 💃 Image 1219 is a dog
# Loaded... 💃 Image 1220 is a cat
# Loaded... 💃 Image 1221 is a dog
# Loaded... 💃 Image 1222 is a cat
# Loaded... 💃 Image 1223 is a cat
# Loaded... 💃 Image 1224 is a dog
# Loaded... 💃 Image 1225 is a dog
# Loaded... 💃 Image 1226 is a cat
# Loaded... 💃 Image 1227 is a dog
# Loaded... 💃 Image 1228 is a dog
# Loaded... 💃 Image 1229 is a dog
# Loaded... 💃 Image 1230 is a dog
# Loaded... 💃 Image 1231 is a cat
# Loaded... 💃 Image 1232 is a dog
# Loaded... 💃 Image 1233 is a dog
# Loaded... 💃 Image 1234 is a cat
# Loaded... 💃 Image 1235 is a dog
# Loaded... 💃 Image 1236 is a dog
# Loaded... 💃 Image 1237 is a dog
# Loaded... 💃 Image 1238 is a cat
# Loaded... 💃 Image 1239 is a cat
# Loaded... 💃 Image 1240 is a dog
# Loaded... 💃 Image 1241 is a cat
# Loaded... 💃 Image 1242 is a dog
# Loaded... 💃 Image 1243 is a cat
# Loaded... 💃 Image 1244 is a dog
# Loaded... 💃 Image 1245 is a cat
# Loaded... 💃 Image 1246 is a cat
# Loaded... 💃 Image 1247 is a cat
# Loaded... 💃 Image 1248 is a cat
# Loaded... 💃 Image 1249 is a cat
# Loaded... 💃 Image 1250 is a dog
# Loaded... 💃 Image 1251 is a cat
# Loaded... 💃 Image 1252 is a dog
# Loaded... 💃 Image 1253 is a dog
# Loaded... 💃 Image 1254 is a dog
# Loaded... 💃 Image 1255 is a cat
# Loaded... 💃 Image 1256 is a cat
# Loaded... 💃 Image 1257 is a dog
# Loaded... 💃 Image 1258 is a cat
# Loaded... 💃 Image 1259 is a dog
# Loaded... 💃 Image 1260 is a cat
# Loaded... 💃 Image 1261 is a dog
# Loaded... 💃 Image 1262 is a cat
# Loaded... 💃 Image 1263 is a cat
# Loaded... 💃 Image 1264 is a dog
# Loaded... 💃 Image 1265 is a cat
# Loaded... 💃 Image 1266 is a dog
# Loaded... 💃 Image 1267 is a dog
# Loaded... 💃 Image 1268 is a dog
# Loaded... 💃 Image 1269 is a dog
# Loaded... 💃 Image 1270 is a dog
# Loaded... 💃 Image 1271 is a dog
# Loaded... 💃 Image 1272 is a cat
# Loaded... 💃 Image 1273 is a cat
# Loaded... 💃 Image 1274 is a cat
# Loaded... 💃 Image 1275 is a cat
# Loaded... 💃 Image 1276 is a cat
# Loaded... 💃 Image 1277 is a cat
# Loaded... 💃 Image 1278 is a dog
# Loaded... 💃 Image 1279 is a cat
# Loaded... 💃 Image 1280 is a dog
# Loaded... 💃 Image 1281 is a cat
# Loaded... 💃 Image 1282 is a cat
# Loaded... 💃 Image 1283 is a dog
# Loaded... 💃 Image 1284 is a dog
# Loaded... 💃 Image 1285 is a cat
# Loaded... 💃 Image 1286 is a dog
# Loaded... 💃 Image 1287 is a dog
# Loaded... 💃 Image 1288 is a dog
# Loaded... 💃 Image 1289 is a dog
# Loaded... 💃 Image 1290 is a cat
# Loaded... 💃 Image 1291 is a dog
# Loaded... 💃 Image 1292 is a cat
# Loaded... 💃 Image 1293 is a cat
# Loaded... 💃 Image 1294 is a dog
# Loaded... 💃 Image 1295 is a cat
# Loaded... 💃 Image 1296 is a dog
# Loaded... 💃 Image 1297 is a dog
# Loaded... 💃 Image 1298 is a dog
# Loaded... 💃 Image 1299 is a cat
# Loaded... 💃 Image 1300 is a cat
# Loaded... 💃 Image 1301 is a cat
# Loaded... 💃 Image 1302 is a cat
# Loaded... 💃 Image 1303 is a dog
# Loaded... 💃 Image 1304 is a cat
# Loaded... 💃 Image 1305 is a cat
# Loaded... 💃 Image 1306 is a dog
# Loaded... 💃 Image 1307 is a cat
# Loaded... 💃 Image 1308 is a dog
# Loaded... 💃 Image 1309 is a cat
# Loaded... 💃 Image 1310 is a cat
# Loaded... 💃 Image 1311 is a cat
# Loaded... 💃 Image 1312 is a cat
# Loaded... 💃 Image 1313 is a cat
# Loaded... 💃 Image 1314 is a dog
# Loaded... 💃 Image 1315 is a cat
# Loaded... 💃 Image 1316 is a dog
# Loaded... 💃 Image 1317 is a cat
# Loaded... 💃 Image 1318 is a cat
# Loaded... 💃 Image 1319 is a dog
# Loaded... 💃 Image 1320 is a dog
# Loaded... 💃 Image 1321 is a dog
# Loaded... 💃 Image 1322 is a dog
# Loaded... 💃 Image 1323 is a dog
# Loaded... 💃 Image 1324 is a dog
# Loaded... 💃 Image 1325 is a dog
# Loaded... 💃 Image 1326 is a cat
# Loaded... 💃 Image 1327 is a dog
# Loaded... 💃 Image 1328 is a dog
# Loaded... 💃 Image 1329 is a cat
# Loaded... 💃 Image 1330 is a dog
# Loaded... 💃 Image 1331 is a dog
# Loaded... 💃 Image 1332 is a cat
# Loaded... 💃 Image 1333 is a dog
# Loaded... 💃 Image 1334 is a cat
# Loaded... 💃 Image 1335 is a cat
# Loaded... 💃 Image 1336 is a cat
# Loaded... 💃 Image 1337 is a cat
# Loaded... 💃 Image 1338 is a dog
# Loaded... 💃 Image 1339 is a dog
# Loaded... 💃 Image 1340 is a dog
# Loaded... 💃 Image 1341 is a cat
# Loaded... 💃 Image 1342 is a dog
# Loaded... 💃 Image 1343 is a dog
# Loaded... 💃 Image 1344 is a cat
# Loaded... 💃 Image 1345 is a dog
# Loaded... 💃 Image 1346 is a cat
# Loaded... 💃 Image 1347 is a dog
# Loaded... 💃 Image 1348 is a cat
# Loaded... 💃 Image 1349 is a dog
# Loaded... 💃 Image 1350 is a dog
# Loaded... 💃 Image 1351 is a cat
# Loaded... 💃 Image 1352 is a dog
# Loaded... 💃 Image 1353 is a cat
# Loaded... 💃 Image 1354 is a cat
# Loaded... 💃 Image 1355 is a cat
# Loaded... 💃 Image 1356 is a dog
# Loaded... 💃 Image 1357 is a cat
# Loaded... 💃 Image 1358 is a cat
# Loaded... 💃 Image 1359 is a dog
# Loaded... 💃 Image 1360 is a dog
# Loaded... 💃 Image 1361 is a dog
# Loaded... 💃 Image 1362 is a cat
# Loaded... 💃 Image 1363 is a dog
# Loaded... 💃 Image 1364 is a cat
# Loaded... 💃 Image 1365 is a dog
# Loaded... 💃 Image 1366 is a dog
# Loaded... 💃 Image 1367 is a cat
# Loaded... 💃 Image 1368 is a dog
# Loaded... 💃 Image 1369 is a cat
# Loaded... 💃 Image 1370 is a cat
# Loaded... 💃 Image 1371 is a dog
# Loaded... 💃 Image 1372 is a cat
# Loaded... 💃 Image 1373 is a dog
# Loaded... 💃 Image 1374 is a cat
# Loaded... 💃 Image 1375 is a dog
# Loaded... 💃 Image 1376 is a dog
# Loaded... 💃 Image 1377 is a cat
# Loaded... 💃 Image 1378 is a dog
# Loaded... 💃 Image 1379 is a dog
# Loaded... 💃 Image 1380 is a dog
# Loaded... 💃 Image 1381 is a cat
# Loaded... 💃 Image 1382 is a dog
# Loaded... 💃 Image 1383 is a cat
# Loaded... 💃 Image 1384 is a cat
# Loaded... 💃 Image 1385 is a dog
# Loaded... 💃 Image 1386 is a dog
# Loaded... 💃 Image 1387 is a cat
# Loaded... 💃 Image 1388 is a cat
# Loaded... 💃 Image 1389 is a dog
# Loaded... 💃 Image 1390 is a dog
# Loaded... 💃 Image 1391 is a cat
# Loaded... 💃 Image 1392 is a cat
# Loaded... 💃 Image 1393 is a cat
# Loaded... 💃 Image 1394 is a dog
# Loaded... 💃 Image 1395 is a cat
# Loaded... 💃 Image 1396 is a cat
# Loaded... 💃 Image 1397 is a cat
# Loaded... 💃 Image 1398 is a cat
# Loaded... 💃 Image 1399 is a dog
# Loaded... 💃 Image 1400 is a cat
# Loaded... 💃 Image 1401 is a cat
# Loaded... 💃 Image 1402 is a cat
# Loaded... 💃 Image 1403 is a cat
# Loaded... 💃 Image 1404 is a dog
# Loaded... 💃 Image 1405 is a cat
# Loaded... 💃 Image 1406 is a cat
# Loaded... 💃 Image 1407 is a dog
# Loaded... 💃 Image 1408 is a dog
# Loaded... 💃 Image 1409 is a dog
# Loaded... 💃 Image 1410 is a cat
# Loaded... 💃 Image 1411 is a dog
# Loaded... 💃 Image 1412 is a dog
# Loaded... 💃 Image 1413 is a cat
# Loaded... 💃 Image 1414 is a cat
# Loaded... 💃 Image 1415 is a dog
# Loaded... 💃 Image 1416 is a cat
# Loaded... 💃 Image 1417 is a dog
# Loaded... 💃 Image 1418 is a dog
# Loaded... 💃 Image 1419 is a dog
# Loaded... 💃 Image 1420 is a cat
# Loaded... 💃 Image 1421 is a cat
# Loaded... 💃 Image 1422 is a dog
# Loaded... 💃 Image 1423 is a dog
# Loaded... 💃 Image 1424 is a dog
# Loaded... 💃 Image 1425 is a cat
# Loaded... 💃 Image 1426 is a dog
# Loaded... 💃 Image 1427 is a cat
# Loaded... 💃 Image 1428 is a dog
# Loaded... 💃 Image 1429 is a dog
# Loaded... 💃 Image 1430 is a dog
# Loaded... 💃 Image 1431 is a cat
# Loaded... 💃 Image 1432 is a cat
# Loaded... 💃 Image 1433 is a cat
# Loaded... 💃 Image 1434 is a cat
# Loaded... 💃 Image 1435 is a cat
# Loaded... 💃 Image 1436 is a dog
# Loaded... 💃 Image 1437 is a dog
# Loaded... 💃 Image 1438 is a dog
# Loaded... 💃 Image 1439 is a cat
# Loaded... 💃 Image 1440 is a dog
# Loaded... 💃 Image 1441 is a cat
# Loaded... 💃 Image 1442 is a dog
# Loaded... 💃 Image 1443 is a cat
# Loaded... 💃 Image 1444 is a dog
# Loaded... 💃 Image 1445 is a dog
# Loaded... 💃 Image 1446 is a cat
# Loaded... 💃 Image 1447 is a cat
# Loaded... 💃 Image 1448 is a cat
# Loaded... 💃 Image 1449 is a dog
# Loaded... 💃 Image 1450 is a cat
# Loaded... 💃 Image 1451 is a cat
# Loaded... 💃 Image 1452 is a dog
# Loaded... 💃 Image 1453 is a dog
# Loaded... 💃 Image 1454 is a dog
# Loaded... 💃 Image 1455 is a cat
# Loaded... 💃 Image 1456 is a cat
# Loaded... 💃 Image 1457 is a cat
# Loaded... 💃 Image 1458 is a dog
# Loaded... 💃 Image 1459 is a dog
# Loaded... 💃 Image 1460 is a dog
# Loaded... 💃 Image 1461 is a cat
# Loaded... 💃 Image 1462 is a cat
# Loaded... 💃 Image 1463 is a cat
# Loaded... 💃 Image 1464 is a cat
# Loaded... 💃 Image 1465 is a cat
# Loaded... 💃 Image 1466 is a cat
# Loaded... 💃 Image 1467 is a cat
# Loaded... 💃 Image 1468 is a dog
# Loaded... 💃 Image 1469 is a dog
# Loaded... 💃 Image 1470 is a cat
# Loaded... 💃 Image 1471 is a dog
# Loaded... 💃 Image 1472 is a cat
# Loaded... 💃 Image 1473 is a cat
# Loaded... 💃 Image 1474 is a dog
# Loaded... 💃 Image 1475 is a dog
# Loaded... 💃 Image 1476 is a cat
# Loaded... 💃 Image 1477 is a cat
# Loaded... 💃 Image 1478 is a dog
# Loaded... 💃 Image 1479 is a cat
# Loaded... 💃 Image 1480 is a dog
# Loaded... 💃 Image 1481 is a cat
# Loaded... 💃 Image 1482 is a cat
# Loaded... 💃 Image 1483 is a cat
# Loaded... 💃 Image 1484 is a dog
# Loaded... 💃 Image 1485 is a dog
# Loaded... 💃 Image 1486 is a dog
# Loaded... 💃 Image 1487 is a dog
# Loaded... 💃 Image 1488 is a dog
# Loaded... 💃 Image 1489 is a cat
# Loaded... 💃 Image 1490 is a dog
# Loaded... 💃 Image 1491 is a cat
# Loaded... 💃 Image 1492 is a dog
# Loaded... 💃 Image 1493 is a cat
# Loaded... 💃 Image 1494 is a dog
# Loaded... 💃 Image 1495 is a cat
# Loaded... 💃 Image 1496 is a dog
# Loaded... 💃 Image 1497 is a cat
# Loaded... 💃 Image 1498 is a cat
# Loaded... 💃 Image 1499 is a cat
# Loaded... 💃 Image 1500 is a dog
# Loaded... 💃 Image 1501 is a cat
# Loaded... 💃 Image 1502 is a cat
# Loaded... 💃 Image 1503 is a cat
# Loaded... 💃 Image 1504 is a dog
# Loaded... 💃 Image 1505 is a dog
# Loaded... 💃 Image 1506 is a cat
# Loaded... 💃 Image 1507 is a cat
# Loaded... 💃 Image 1508 is a cat
# Loaded... 💃 Image 1509 is a cat
# Loaded... 💃 Image 1510 is a dog
# Loaded... 💃 Image 1511 is a dog
# Loaded... 💃 Image 1512 is a cat
# Loaded... 💃 Image 1513 is a dog
# Loaded... 💃 Image 1514 is a dog
# Loaded... 💃 Image 1515 is a dog
# Loaded... 💃 Image 1516 is a dog
# Loaded... 💃 Image 1517 is a cat
# Loaded... 💃 Image 1518 is a dog
# Loaded... 💃 Image 1519 is a dog
# Loaded... 💃 Image 1520 is a cat
# Loaded... 💃 Image 1521 is a dog
# Loaded... 💃 Image 1522 is a dog
# Loaded... 💃 Image 1523 is a dog
# Loaded... 💃 Image 1524 is a dog
# Loaded... 💃 Image 1525 is a cat
# Loaded... 💃 Image 1526 is a cat
# Loaded... 💃 Image 1527 is a dog
# Loaded... 💃 Image 1528 is a dog
# Loaded... 💃 Image 1529 is a dog
# Loaded... 💃 Image 1530 is a dog
# Loaded... 💃 Image 1531 is a dog
# Loaded... 💃 Image 1532 is a dog
# Loaded... 💃 Image 1533 is a dog
# Loaded... 💃 Image 1534 is a dog
# ...
# Loaded... 💃 Image 3012 is a dog
# Loaded... 💃 Image 3013 is a dog
# Loaded... 💃 Image 3014 is a dog
# Loaded... 💃 Image 3015 is a cat
# Loaded... 💃 Image 3016 is a cat
# Loaded... 💃 Image 3017 is a cat
# Loaded... 💃 Image 3018 is a dog
# Loaded... 💃 Image 3019 is a cat
# Loaded... 💃 Image 3020 is a dog
# Loaded... 💃 Image 3021 is a dog
# Loaded... 💃 Image 3022 is a cat
# Loaded... 💃 Image 3023 is a dog
# Loaded... 💃 Image 3024 is a cat
# Loaded... 💃 Image 3025 is a cat
# Loaded... 💃 Image 3026 is a cat
# Loaded... 💃 Image 3027 is a cat
# Loaded... 💃 Image 3028 is a cat
# Loaded... 💃 Image 3029 is a cat
# Loaded... 💃 Image 3030 is a dog
# Loaded... 💃 Image 3031 is a dog
# Loaded... 💃 Image 3032 is a cat
# Loaded... 💃 Image 3033 is a dog
# Loaded... 💃 Image 3034 is a dog
# Loaded... 💃 Image 3035 is a cat
# Loaded... 💃 Image 3036 is a cat
# Loaded... 💃 Image 3037 is a dog
# Loaded... 💃 Image 3038 is a cat
# Loaded... 💃 Image 3039 is a dog
# Loaded... 💃 Image 3040 is a cat
# Loaded... 💃 Image 3041 is a dog
# Loaded... 💃 Image 3042 is a dog
# Loaded... 💃 Image 3043 is a dog
# Loaded... 💃 Image 3044 is a cat
# Loaded... 💃 Image 3045 is a cat
# Loaded... 💃 Image 3046 is a dog
# Loaded... 💃 Image 3047 is a cat
# Loaded... 💃 Image 3048 is a cat
# Loaded... 💃 Image 3049 is a cat
# Loaded... 💃 Image 3050 is a cat
# Loaded... 💃 Image 3051 is a dog
# Loaded... 💃 Image 3052 is a cat
# Loaded... 💃 Image 3053 is a cat
# Loaded... 💃 Image 3054 is a cat
# Loaded... 💃 Image 3055 is a cat
# Loaded... 💃 Image 3056 is a dog
# Loaded... 💃 Image 3057 is a dog
# Loaded... 💃 Image 3058 is a cat
# Loaded... 💃 Image 3059 is a cat
# Loaded... 💃 Image 3060 is a dog
# Loaded... 💃 Image 3061 is a cat
# Loaded... 💃 Image 3062 is a cat
# Loaded... 💃 Image 3063 is a cat
# Loaded... 💃 Image 3064 is a dog
# Loaded... 💃 Image 3065 is a cat
# Loaded... 💃 Image 3066 is a dog
# Loaded... 💃 Image 3067 is a cat
# Loaded... 💃 Image 3068 is a dog
# Loaded... 💃 Image 3069 is a dog
# Loaded... 💃 Image 3070 is a dog
# Loaded... 💃 Image 3071 is a cat
# Loaded... 💃 Image 3072 is a cat
# Loaded... 💃 Image 3073 is a dog
# Loaded... 💃 Image 3074 is a cat
# Loaded... 💃 Image 3075 is a dog
# Loaded... 💃 Image 3076 is a cat
# Loaded... 💃 Image 3077 is a cat
# Loaded... 💃 Image 3078 is a cat
# Loaded... 💃 Image 3079 is a cat
# Loaded... 💃 Image 3080 is a cat
# Loaded... 💃 Image 3081 is a dog
# Loaded... 💃 Image 3082 is a dog
# Loaded... 💃 Image 3083 is a cat
# Loaded... 💃 Image 3084 is a cat
# Loaded... 💃 Image 3085 is a dog
# Loaded... 💃 Image 3086 is a dog
# Loaded... 💃 Image 3087 is a cat
# Loaded... 💃 Image 3088 is a dog
# Loaded... 💃 Image 3089 is a dog
# Loaded... 💃 Image 3090 is a cat
# Loaded... 💃 Image 3091 is a cat
# Loaded... 💃 Image 3092 is a dog
# Loaded... 💃 Image 3093 is a dog
# Loaded... 💃 Image 3094 is a dog
# Loaded... 💃 Image 3095 is a dog
# Loaded... 💃 Image 3096 is a cat
# Loaded... 💃 Image 3097 is a dog
# Loaded... 💃 Image 3098 is a dog
# Loaded... 💃 Image 3099 is a cat
# Loaded... 💃 Image 3100 is a dog
# Loaded... 💃 Image 3101 is a cat
# Loaded... 💃 Image 3102 is a cat
# Loaded... 💃 Image 3103 is a dog
# Loaded... 💃 Image 3104 is a cat
# Loaded... 💃 Image 3105 is a dog
# Loaded... 💃 Image 3106 is a cat
# Loaded... 💃 Image 3107 is a cat
# Loaded... 💃 Image 3108 is a dog
# Loaded... 💃 Image 3109 is a cat
# Loaded... 💃 Image 3110 is a dog
# Loaded... 💃 Image 3111 is a cat
# Loaded... 💃 Image 3112 is a dog
# Loaded... 💃 Image 3113 is a dog
# Loaded... 💃 Image 3114 is a cat
# Loaded... 💃 Image 3115 is a dog
# Loaded... 💃 Image 3116 is a cat
# Loaded... 💃 Image 3117 is a cat
# Loaded... 💃 Image 3118 is a dog
# Loaded... 💃 Image 3119 is a cat
# Loaded... 💃 Image 3120 is a cat
# Loaded... 💃 Image 3121 is a dog
# Loaded... 💃 Image 3122 is a cat
# Loaded... 💃 Image 3123 is a cat
# Loaded... 💃 Image 3124 is a dog
# Loaded... 💃 Image 3125 is a dog
# Loaded... 💃 Image 3126 is a dog
# Loaded... 💃 Image 3127 is a cat
# Loaded... 💃 Image 3128 is a cat
# Loaded... 💃 Image 3129 is a dog
# Loaded... 💃 Image 3130 is a dog
# Loaded... 💃 Image 3131 is a dog
# Loaded... 💃 Image 3132 is a cat
# Loaded... 💃 Image 3133 is a cat
# Loaded... 💃 Image 3134 is a cat
# Loaded... 💃 Image 3135 is a dog
# Loaded... 💃 Image 3136 is a cat
# Loaded... 💃 Image 3137 is a cat
# Loaded... 💃 Image 3138 is a cat
# Loaded... 💃 Image 3139 is a cat
# Loaded... 💃 Image 3140 is a cat
# Loaded... 💃 Image 3141 is a dog
# Loaded... 💃 Image 3142 is a cat
# Loaded... 💃 Image 3143 is a dog
# Loaded... 💃 Image 3144 is a cat
# Loaded... 💃 Image 3145 is a cat
# Loaded... 💃 Image 3146 is a dog
# Loaded... 💃 Image 3147 is a dog
# Loaded... 💃 Image 3148 is a dog
# Loaded... 💃 Image 3149 is a cat
# Loaded... 💃 Image 3150 is a dog
# Loaded... 💃 Image 3151 is a dog
# Loaded... 💃 Image 3152 is a cat
# Loaded... 💃 Image 3153 is a dog
# Loaded... 💃 Image 3154 is a dog
# Loaded... 💃 Image 3155 is a cat
# Loaded... 💃 Image 3156 is a cat
# Loaded... 💃 Image 3157 is a dog
# Loaded... 💃 Image 3158 is a dog
# Loaded... 💃 Image 3159 is a dog
# Loaded... 💃 Image 3160 is a dog
# Loaded... 💃 Image 3161 is a cat
# Loaded... 💃 Image 3162 is a dog
# Loaded... 💃 Image 3163 is a dog
# Loaded... 💃 Image 3164 is a cat
# Loaded... 💃 Image 3165 is a cat
# Loaded... 💃 Image 3166 is a dog
# Loaded... 💃 Image 3167 is a dog
# Loaded... 💃 Image 3168 is a cat
# Loaded... 💃 Image 3169 is a dog
# Loaded... 💃 Image 3170 is a dog
# Loaded... 💃 Image 3171 is a dog
# Loaded... 💃 Image 3172 is a cat
# Loaded... 💃 Image 3173 is a cat
# Loaded... 💃 Image 3174 is a cat
# Loaded... 💃 Image 3175 is a cat
# Loaded... 💃 Image 3176 is a dog
# Loaded... 💃 Image 3177 is a cat
# Loaded... 💃 Image 3178 is a dog
# Loaded... 💃 Image 3179 is a dog
# Loaded... 💃 Image 3180 is a cat
# Loaded... 💃 Image 3181 is a dog
# Loaded... 💃 Image 3182 is a cat
# Loaded... 💃 Image 3183 is a dog
# Loaded... 💃 Image 3184 is a dog
# Loaded... 💃 Image 3185 is a cat
# Loaded... 💃 Image 3186 is a dog
# Loaded... 💃 Image 3187 is a dog
# Loaded... 💃 Image 3188 is a dog
# Loaded... 💃 Image 3189 is a cat
# Loaded... 💃 Image 3190 is a dog
# Loaded... 💃 Image 3191 is a cat
# Loaded... 💃 Image 3192 is a cat
# Loaded... 💃 Image 3193 is a cat
# Loaded... 💃 Image 3194 is a cat
# Loaded... 💃 Image 3195 is a dog
# Loaded... 💃 Image 3196 is a cat
# Loaded... 💃 Image 3197 is a dog
# Loaded... 💃 Image 3198 is a cat
# Loaded... 💃 Image 3199 is a cat
# Loaded... 💃 Image 3200 is a cat
# Loaded... 💃 Image 3201 is a cat
# Loaded... 💃 Image 3202 is a dog
# Loaded... 💃 Image 3203 is a dog
# Loaded... 💃 Image 3204 is a cat
# Loaded... 💃 Image 3205 is a dog
# Loaded... 💃 Image 3206 is a dog
# Loaded... 💃 Image 3207 is a cat
# Loaded... 💃 Image 3208 is a dog
# Loaded... 💃 Image 3209 is a dog
# Loaded... 💃 Image 3210 is a dog
# Loaded... 💃 Image 3211 is a cat
# Loaded... 💃 Image 3212 is a cat
# Loaded... 💃 Image 3213 is a cat
# Loaded... 💃 Image 3214 is a cat
# Loaded... 💃 Image 3215 is a cat
# Loaded... 💃 Image 3216 is a cat
# Loaded... 💃 Image 3217 is a cat
# Loaded... 💃 Image 3218 is a cat
# Loaded... 💃 Image 3219 is a cat
# Loaded... 💃 Image 3220 is a cat
# Loaded... 💃 Image 3221 is a dog
# Loaded... 💃 Image 3222 is a dog
# Loaded... 💃 Image 3223 is a cat
# Loaded... 💃 Image 3224 is a cat
# Loaded... 💃 Image 3225 is a dog
# Loaded... 💃 Image 3226 is a cat
# Loaded... 💃 Image 3227 is a cat
# Loaded... 💃 Image 3228 is a cat
# Loaded... 💃 Image 3229 is a dog
# Loaded... 💃 Image 3230 is a cat
# Loaded... 💃 Image 3231 is a dog
# Loaded... 💃 Image 3232 is a dog
# Loaded... 💃 Image 3233 is a cat
# Loaded... 💃 Image 3234 is a cat
# Loaded... 💃 Image 3235 is a dog
# Loaded... 💃 Image 3236 is a dog
# Loaded... 💃 Image 3237 is a cat
# Loaded... 💃 Image 3238 is a dog
# Loaded... 💃 Image 3239 is a cat
# Loaded... 💃 Image 3240 is a dog
# Loaded... 💃 Image 3241 is a cat
# Loaded... 💃 Image 3242 is a dog
# Loaded... 💃 Image 3243 is a cat
# Loaded... 💃 Image 3244 is a dog
# Loaded... 💃 Image 3245 is a dog
# Loaded... 💃 Image 3246 is a dog
# Loaded... 💃 Image 3247 is a cat
# Loaded... 💃 Image 3248 is a cat
# Loaded... 💃 Image 3249 is a dog
# Loaded... 💃 Image 3250 is a dog
# Loaded... 💃 Image 3251 is a cat
# Loaded... 💃 Image 3252 is a dog
# Loaded... 💃 Image 3253 is a cat
# Loaded... 💃 Image 3254 is a dog
# Loaded... 💃 Image 3255 is a cat
# Loaded... 💃 Image 3256 is a cat
# Loaded... 💃 Image 3257 is a dog
# Loaded... 💃 Image 3258 is a dog
# Loaded... 💃 Image 3259 is a cat
# Loaded... 💃 Image 3260 is a dog
# Loaded... 💃 Image 3261 is a dog
# Loaded... 💃 Image 3262 is a dog
# Loaded... 💃 Image 3263 is a cat
# Loaded... 💃 Image 3264 is a cat
# Loaded... 💃 Image 3265 is a dog
# Loaded... 💃 Image 3266 is a cat
# Loaded... 💃 Image 3267 is a cat
# Loaded... 💃 Image 3268 is a cat
# Loaded... 💃 Image 3269 is a dog
# Loaded... 💃 Image 3270 is a cat
# Loaded... 💃 Image 3271 is a cat
# Loaded... 💃 Image 3272 is a dog
# Loaded... 💃 Image 3273 is a dog
# Loaded... 💃 Image 3274 is a cat
# Loaded... 💃 Image 3275 is a dog
# Loaded... 💃 Image 3276 is a dog
# Loaded... 💃 Image 3277 is a dog
# Loaded... 💃 Image 3278 is a cat
# Loaded... 💃 Image 3279 is a dog
# Loaded... 💃 Image 3280 is a cat
# Loaded... 💃 Image 3281 is a cat
# Loaded... 💃 Image 3282 is a dog
# Loaded... 💃 Image 3283 is a cat
# Loaded... 💃 Image 3284 is a cat
# Loaded... 💃 Image 3285 is a cat
# Loaded... 💃 Image 3286 is a cat
# Loaded... 💃 Image 3287 is a dog
# Loaded... 💃 Image 3288 is a dog
# Loaded... 💃 Image 3289 is a cat
# Loaded... 💃 Image 3290 is a dog
# Loaded... 💃 Image 3291 is a dog
# Loaded... 💃 Image 3292 is a cat
# Loaded... 💃 Image 3293 is a cat
# Loaded... 💃 Image 3294 is a cat
# Loaded... 💃 Image 3295 is a cat
# Loaded... 💃 Image 3296 is a dog
# Loaded... 💃 Image 3297 is a dog
# Loaded... 💃 Image 3298 is a dog
# Loaded... 💃 Image 3299 is a cat
# Loaded... 💃 Image 3300 is a cat
# Loaded... 💃 Image 3301 is a cat
# Loaded... 💃 Image 3302 is a cat
# Loaded... 💃 Image 3303 is a cat
# Loaded... 💃 Image 3304 is a cat
# Loaded... 💃 Image 3305 is a dog
# Loaded... 💃 Image 3306 is a dog
# Loaded... 💃 Image 3307 is a dog
# Loaded... 💃 Image 3308 is a dog
# Loaded... 💃 Image 3309 is a dog
# Loaded... 💃 Image 3310 is a cat
# Loaded... 💃 Image 3311 is a cat
# Loaded... 💃 Image 3312 is a dog
# Loaded... 💃 Image 3313 is a cat
# Loaded... 💃 Image 3314 is a dog
# Loaded... 💃 Image 3315 is a cat
# Loaded... 💃 Image 3316 is a dog
# Loaded... 💃 Image 3317 is a cat
# Loaded... 💃 Image 3318 is a dog
# Loaded... 💃 Image 3319 is a cat
# Loaded... 💃 Image 3320 is a dog
# Loaded... 💃 Image 3321 is a cat
# Loaded... 💃 Image 3322 is a dog
# Loaded... 💃 Image 3323 is a dog
# Loaded... 💃 Image 3324 is a cat
# Loaded... 💃 Image 3325 is a dog
# Loaded... 💃 Image 3326 is a cat
# Loaded... 💃 Image 3327 is a dog
# Loaded... 💃 Image 3328 is a dog
# Loaded... 💃 Image 3329 is a cat
# Loaded... 💃 Image 3330 is a dog
# Loaded... 💃 Image 3331 is a cat
# Loaded... 💃 Image 3332 is a dog
# Loaded... 💃 Image 3333 is a dog
# Loaded... 💃 Image 3334 is a dog
# Loaded... 💃 Image 3335 is a dog
# Loaded... 💃 Image 3336 is a cat
# Loaded... 💃 Image 3337 is a cat
# Loaded... 💃 Image 3338 is a cat
# Loaded... 💃 Image 3339 is a cat
# Loaded... 💃 Image 3340 is a cat
# Loaded... 💃 Image 3341 is a cat
# Loaded... 💃 Image 3342 is a dog
# Loaded... 💃 Image 3343 is a dog
# Loaded... 💃 Image 3344 is a dog
# Loaded... 💃 Image 3345 is a dog
# Loaded... 💃 Image 3346 is a cat
# Loaded... 💃 Image 3347 is a dog
# Loaded... 💃 Image 3348 is a cat
# Loaded... 💃 Image 3349 is a cat
# Loaded... 💃 Image 3350 is a dog
# Loaded... 💃 Image 3351 is a cat
# Loaded... 💃 Image 3352 is a cat
# Loaded... 💃 Image 3353 is a cat
# Loaded... 💃 Image 3354 is a dog
# Loaded... 💃 Image 3355 is a cat
# Loaded... 💃 Image 3356 is a cat
# Loaded... 💃 Image 3357 is a dog
# Loaded... 💃 Image 3358 is a cat
# Loaded... 💃 Image 3359 is a cat
# Loaded... 💃 Image 3360 is a dog
# Loaded... 💃 Image 3361 is a dog
# Loaded... 💃 Image 3362 is a cat
# Loaded... 💃 Image 3363 is a dog
# Loaded... 💃 Image 3364 is a cat
# Loaded... 💃 Image 3365 is a dog
# Loaded... 💃 Image 3366 is a cat
# Loaded... 💃 Image 3367 is a cat
# Loaded... 💃 Image 3368 is a dog
# Loaded... 💃 Image 3369 is a dog
# Loaded... 💃 Image 3370 is a dog
# Loaded... 💃 Image 3371 is a cat
# Loaded... 💃 Image 3372 is a cat
# Loaded... 💃 Image 3373 is a cat
# Loaded... 💃 Image 3374 is a cat
# Loaded... 💃 Image 3375 is a dog
# Loaded... 💃 Image 3376 is a cat
# Loaded... 💃 Image 3377 is a cat
# Loaded... 💃 Image 3378 is a dog
# Loaded... 💃 Image 3379 is a cat
# Loaded... 💃 Image 3380 is a cat
# Loaded... 💃 Image 3381 is a dog
# Loaded... 💃 Image 3382 is a cat
# Loaded... 💃 Image 3383 is a dog
# Loaded... 💃 Image 3384 is a dog
# Loaded... 💃 Image 3385 is a cat
# Loaded... 💃 Image 3386 is a dog
# Loaded... 💃 Image 3387 is a cat
# Loaded... 💃 Image 3388 is a cat
# Loaded... 💃 Image 3389 is a cat
# Loaded... 💃 Image 3390 is a cat
# Loaded... 💃 Image 3391 is a cat
# Loaded... 💃 Image 3392 is a cat
# Loaded... 💃 Image 3393 is a dog
# Loaded... 💃 Image 3394 is a cat
# Loaded... 💃 Image 3395 is a cat
# Loaded... 💃 Image 3396 is a dog
# Loaded... 💃 Image 3397 is a dog
# Loaded... 💃 Image 3398 is a cat
# Loaded... 💃 Image 3399 is a dog
# Loaded... 💃 Image 3400 is a dog
# Loaded... 💃 Image 3401 is a cat
# Loaded... 💃 Image 3402 is a dog
# Loaded... 💃 Image 3403 is a dog
# Loaded... 💃 Image 3404 is a cat
# Loaded... 💃 Image 3405 is a dog
# Loaded... 💃 Image 3406 is a dog
# Loaded... 💃 Image 3407 is a cat
# Loaded... 💃 Image 3408 is a cat
# Loaded... 💃 Image 3409 is a dog
# Loaded... 💃 Image 3410 is a cat
# Loaded... 💃 Image 3411 is a dog
# Loaded... 💃 Image 3412 is a dog
# Loaded... 💃 Image 3413 is a dog
# Loaded... 💃 Image 3414 is a cat
# Loaded... 💃 Image 3415 is a cat
# Loaded... 💃 Image 3416 is a cat
# Loaded... 💃 Image 3417 is a dog
# Loaded... 💃 Image 3418 is a cat
# Loaded... 💃 Image 3419 is a cat
# Loaded... 💃 Image 3420 is a dog
# Loaded... 💃 Image 3421 is a dog
# Loaded... 💃 Image 3422 is a cat
# Loaded... 💃 Image 3423 is a cat
# Loaded... 💃 Image 3424 is a cat
# Loaded... 💃 Image 3425 is a dog
# Loaded... 💃 Image 3426 is a cat
# Loaded... 💃 Image 3427 is a cat
# Loaded... 💃 Image 3428 is a cat
# Loaded... 💃 Image 3429 is a cat
# Loaded... 💃 Image 3430 is a dog
# Loaded... 💃 Image 3431 is a cat
# Loaded... 💃 Image 3432 is a dog
# Loaded... 💃 Image 3433 is a cat
# Loaded... 💃 Image 3434 is a cat
# Loaded... 💃 Image 3435 is a dog
# Loaded... 💃 Image 3436 is a cat
# Loaded... 💃 Image 3437 is a dog
# Loaded... 💃 Image 3438 is a cat
# Loaded... 💃 Image 3439 is a cat
# Loaded... 💃 Image 3440 is a dog
# Loaded... 💃 Image 3441 is a cat
# Loaded... 💃 Image 3442 is a dog
# Loaded... 💃 Image 3443 is a dog
# Loaded... 💃 Image 3444 is a cat
# Loaded... 💃 Image 3445 is a dog
# Loaded... 💃 Image 3446 is a dog
# Loaded... 💃 Image 3447 is a dog
# Loaded... 💃 Image 3448 is a dog
# Loaded... 💃 Image 3449 is a cat
# Loaded... 💃 Image 3450 is a cat
# Loaded... 💃 Image 3451 is a dog
# Loaded... 💃 Image 3452 is a cat
# Loaded... 💃 Image 3453 is a dog
# Loaded... 💃 Image 3454 is a cat
# Loaded... 💃 Image 3455 is a dog
# Loaded... 💃 Image 3456 is a dog
# Loaded... 💃 Image 3457 is a cat
# Loaded... 💃 Image 3458 is a dog
# Loaded... 💃 Image 3459 is a cat
# Loaded... 💃 Image 3460 is a cat
# Loaded... 💃 Image 3461 is a cat
# Loaded... 💃 Image 3462 is a dog
# Loaded... 💃 Image 3463 is a cat
# Loaded... 💃 Image 3464 is a cat
# Loaded... 💃 Image 3465 is a cat
# Loaded... 💃 Image 3466 is a dog
# Loaded... 💃 Image 3467 is a dog
# Loaded... 💃 Image 3468 is a cat
# Loaded... 💃 Image 3469 is a cat
# Loaded... 💃 Image 3470 is a dog
# Loaded... 💃 Image 3471 is a dog
# Loaded... 💃 Image 3472 is a cat
# Loaded... 💃 Image 3473 is a dog
# Loaded... 💃 Image 3474 is a cat
# Loaded... 💃 Image 3475 is a cat
# Loaded... 💃 Image 3476 is a dog
# Loaded... 💃 Image 3477 is a cat
# Loaded... 💃 Image 3478 is a dog
# Loaded... 💃 Image 3479 is a dog
# Loaded... 💃 Image 3480 is a dog
# Loaded... 💃 Image 3481 is a dog
# Loaded... 💃 Image 3482 is a cat
# Loaded... 💃 Image 3483 is a cat
# Loaded... 💃 Image 3484 is a cat
# Loaded... 💃 Image 3485 is a dog
# Loaded... 💃 Image 3486 is a cat
# Loaded... 💃 Image 3487 is a cat
# Loaded... 💃 Image 3488 is a dog
# Loaded... 💃 Image 3489 is a cat
# Loaded... 💃 Image 3490 is a cat
# Loaded... 💃 Image 3491 is a cat
# Loaded... 💃 Image 3492 is a dog
# Loaded... 💃 Image 3493 is a dog
# Loaded... 💃 Image 3494 is a dog
# Loaded... 💃 Image 3495 is a dog
# Loaded... 💃 Image 3496 is a dog
# Loaded... 💃 Image 3497 is a dog
# Loaded... 💃 Image 3498 is a dog
# Loaded... 💃 Image 3499 is a cat
# Loaded... 💃 Image 3500 is a dog
# Loaded... 💃 Image 3501 is a cat
# Loaded... 💃 Image 3502 is a cat
# Loaded... 💃 Image 3503 is a cat
# Loaded... 💃 Image 3504 is a dog
# Loaded... 💃 Image 3505 is a dog
# Loaded... 💃 Image 3506 is a dog
# Loaded... 💃 Image 3507 is a cat
# Loaded... 💃 Image 3508 is a dog
# Loaded... 💃 Image 3509 is a dog
# Loaded... 💃 Image 3510 is a dog
# Loaded... 💃 Image 3511 is a dog

# %% [markdown]
# Create an array of the <code>train_images</code> and <code>train_labels</code>. <code>OpenCV</code> only identifies arrays of type <code>float32</code> for the training samples and array of shape <code>(label size, 1)</code> for the training labels. We can do that by specifying <code>astype('float32')</code> on the numpy array of the training samples and convert the training labels to integers and <code>reshape</code> the array to <code>(label size, 1)</code>. When you print the <code>train_labels</code>, the array will look like this <code>\[\[1], \[0], ..., \[0]]</code></p>

# %%
train_images = np.array(train_images).astype('float32')
train_labels = np.array(train_labels)

# %%
train_labels = train_labels.astype(int)
train_labels = train_labels.reshape((train_labels.size,1))
print(train_labels)
# Out:
# [[0]
#  [1]
#  [0]
#  ...
#  [0]
#  [0]
#  [0]]

# %% [markdown]
# Split data into training and test set with a test size of your choice:

# %%
test_size = 0.2
train_samples, test_samples, train_labels, test_labels = train_test_split(
    train_images, train_labels, test_size=test_size, random_state=0)

# %% [markdown]
# To train the KNN model, we will use the <code>cv2.ml.KNearest_create()</code> from the <code>OpenCV</code> library. We need to define how many nearest neighbors will be used for classification as a hyper-parameter k. This parameter k can be toggled with/tuned in the training or model validation process. Fit the training and test images and get the accuracy score of the model.
#
# We will try multiple values of <code>k</code> to find the optimal value for the dataset we have. <code>k</code> refers to the number of nearest neighbours to include in the majority of the voting process.
#
# <i>Note:</i> Depending on how large your dataset is, it may take a few seconds to run.

# %%
start_datetime = datetime.now()

knn = cv2.ml.KNearest_create()
knn.train(train_samples, cv2.ml.ROW_SAMPLE, train_labels)

## get different values of K
k_values = [1, 2, 3, 4, 5]
k_result = []
for k in k_values:
    ret,result,neighbours,dist = knn.findNearest(test_samples,k=k)
    k_result.append(result)
flattened = []
for res in k_result:
    flat_result = [item for sublist in res for item in sublist]
    flattened.append(flat_result)

end_datetime = datetime.now()
print('Training Duration: ' + str(end_datetime-start_datetime))
# Out:
# Training Duration: 0:00:07.825857

# %% [markdown]
# We will get the accuracy value for each value of <code>k</code> i.e., how many percent of the images were classified correctly? We will create a confusion matrix for a more comprehensive classification model evaluation.

# %%
## create an empty list to save accuracy and the cofusion matrix
accuracy_res = []
con_matrix = []
## we will use a loop because we have multiple value of k
for k_res in k_result:
    label_names = [0, 1]
    cmx = confusion_matrix(test_labels, k_res, labels=label_names)
    con_matrix.append(cmx)
    ## get values for when we predict accurately
    matches = k_res==test_labels
    correct = np.count_nonzero(matches)
    ## calculate accuracy
    accuracy = correct*100.0/result.size
    accuracy_res.append(accuracy)
## stor accuracy for later when we create the graph
res_accuracy = {k_values[i]: accuracy_res[i] for i in range(len(k_values))}
list_res = sorted(res_accuracy.items())

# %% [markdown]
# **A Quick Guide to the Confusion Matrix**

# %% [markdown]
# A confusion matrix is a performance measurement for classification problem. It is a table with a combination of predicted and actual values. On the y-axis, we have the `True` label and on the x-axis we have the `Predicted` label. This example will focus on a binary classifier, i.e. a yes or no model.
#
# <table>
#   <tr>
#     <td>&nbsp;</td>
#     <td>Predicted: NO</td>
#     <td>Predicted: YES</td>
#   </tr>
#   <tr>
#     <td>True: NO</td>
#     <td>30</td>
#     <td>30</td>
#   </tr>
#   <tr>
#     <td>True: YES</td>
#     <td>10</td>
#     <td>50</td>
#   </tr>
# </table>
#
# In this matrix, we can see that there are two classes. For example, if we were predicting if an image is a hotdog, "yes" will be a hotdog and "no" will be not a hotdog. We have 120 predictions and out of those times, the classifier predicted "yes" 80 times and "no" 40 times but really, there were 60 "yes"s and 60 "no"s.
#
# When we talk about confusion matrix, we talk about a few terms:
#
# *   True Positive (TP): Our model predicted "yes", and it was actually "yes"
# *   True Negative (TN): Our model predicted "no", and it was actually "no"
# *   False Positive (FP): Our model predicted "yes", but it was actually "no"
# *   False Negative (FN): Our model predicted "no", but it was actually "yes"
#
# Let's look at it in the context of our example:
#
# <table>
#   <tr>
#     <td>&nbsp;</td>
#     <td>Predicted: NO</td>
#     <td>Predicted: YES</td>
#   </tr>
#   <tr>
#     <td>True: NO</td>
#     <td>TN = 30</td>
#     <td>FP = 30</td>
#     <td>60</td>
#   </tr>
#   <tr>
#     <td>True: YES</td>
#     <td>FN = 10</td>
#     <td>TP = 50</td>
#     <td>60</td>
#   </tr>
#   <tr>
#     <td>&nbsp;</td>
#     <td>40</td>
#     <td>80</td>
#   </tr>
# </table>
#
# **Accuracy** is the number the model got right over the total number of predictions. This is (TP+TN)/Total Number of Oredictions.

# %% [markdown]
# Now let's visualize the confusion matrix:

# %%
t=0
## for each value of k we will create a confusion matrix
for array in con_matrix:
    df_cm = pd.DataFrame(array)
    sns.set(font_scale=1.4) # for label size
    sns.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt = ".0f") # font size
    t += 1
    title = "Confusion Matrix for k equals " + str(t)
    plt.title(title)
    plt.show()

# %% [markdown]
# We will plot the accuracy to see which one is highest i.e., what percentage of images were classified correctly?

# %%
## plot accuracy against 
x, y = zip(*list_res)
plt.plot(x, y)
plt.show()

# %% [markdown]
# We will get the best value of <code>k</code> to train the model to test the model on our image:

# %%
k_best = max(list_res,key=lambda item:item[1])[0]
k_best
# Out:
# 1

# %% [markdown]
# ## Let's Report Our Results Back to CV Studio

# %%
parameters = {
    'k_best': k_best
}
result = cvstudioClient.report(started=start_datetime, completed=end_datetime, parameters=parameters, accuracy=list_res)

if result.ok:
    print('Congratulations your results have been reported back to CV Studio!')

# %% [markdown]
# Save the KNN model to a file:

# %%
knn.save('knn_samples.yml')

# %% [markdown]
# 👈🏾 Check that the `knn_samples.yml` was saved to your directory.
#
# Now let's save the model back to CV Studio:

# %%
result = cvstudioClient.uploadModel('knn_samples.yml', {'k_best': k_best})
# Out:
# File Uploaded

# %% [markdown]
# # Awesome! Now What's Next?

# %% [markdown]
# We will now head back to the `Train` section of 👉🏾 <a href="https://vision.skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-cvstudio-2021-01-01"> CV Studio</a> 👈🏾 to take a look at our model parameters and then create a <code>Application</code>.
#
# The next section will have a notebook that will:
#
# <ul>
#     <li>Load our saved model</li>
#     <li>Use the best value of <code>k</code></li>
#     <li>Let you upload your image and test the model</li>
# </ul>

# %% [markdown]
# To create an <code>Application</code> run, click on **Use Model** at the left hand corner, and click **New Application** at the right hand to create a New Use Application and **Launch Notebook**
#
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images/Screen_Shot_2021-04-16_at_11.59.21_AM.png" width="1000" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# Now let's go...
#
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images/cat_giphy.gif" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# <h2>Authors</h2>

# %% [markdown]
# [Aije Egwaikhide](https://www.linkedin.com/in/aije-egwaikhide/?utm_medium=Exinfluencer\&utm_source=Exinfluencer\&utm_content=000026UJ\&utm_term=10006555\&utm_id=NA-SkillsNetwork-Channel-cvstudio-2021-01-01) is a Data Scientist at IBM who holds a degree in Economics and Statistics from the University of Manitoba and a Post-grad in Business Analytics from St. Lawrence College, Kingston. She is currently pursuing her Masters in Management Analytics at Queens University. She is part of the IBM Developer Skills Network group where she brings her real-world experience to the courses she creates.

# %% [markdown]
# <h2>Change Log</h2>

# %% [markdown]
# <table>
#     <tr>
#         <th>Date (YYYY-MM-DD)</th>
#         <th>Version</th>
#         <th>Changed By</th>
#         <th>Change Description</th>
#     </tr>
#         <tr>
#         <td>2021-05-25</td>
#         <td>1.2</td>
#         <td>Kathy</td>
#         <td>Modified multiple areas</td>
#     </tr>
#     <tr>
#         <td>2021-05-25</td>
#         <td>1.2</td>
#         <td>Yasmine</td>
#         <td>Modified multiple areas</td>
#     </tr>
#     <tr>
#         <td>2021-04-10</td>
#         <td>1.1</td>
#         <td>Aije</td>
#         <td>Fixed grammatical errors</td>
#     </tr>
#      <tr>
#         <td>2021-04-09</td>
#         <td>1.0</td>
#         <td>Aije</td>
#         <td>Updated to new template</td>
#     </tr>
#     <tr>
#         <td>2021-02-24</td>
#         <td>0.1</td>
#         <td>Aije</td>
#         <td>Created original version of the lab</td>
#     </tr>
# </table>

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
